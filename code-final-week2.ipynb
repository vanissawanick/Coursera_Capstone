# %% [markdown]
# # Data science / Capstone project – code (week 2)
# ### The battle of the neighbourhoods: which one is more multicultural? Southampton vs Portsmouth

# %% [markdown]
# ### Step 1 - gather data from each neighbourhood
# In this case, the starting point is the train station from each city. We will use Foursquare for that.
#
# ### Step 2 - group by category using the mean
# For that, we need to group the lists
#
# ### Step 3 - add to a dataframe
# By adding to the dataframe then we can use to cluster them. There will be 2 dataframes, one for each city.
#
# ### Step 4 - use k-means to cluster the neighbourhoods
# Cluster the dataframes first.
#
# ### Step 5 - compare the clusters
# Now compare the dataframes + clusters from each. Might use a map for that.

# %% [markdown]
# ### Import libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import os
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.20.0               |             py_0          57 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     certifi-2019.9.11          |           py36_0         147 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         238 KB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib: 1.50-py_0        conda-forge
#     geopy:         1.20.0-py_0      conda-forge
#
# The following packages will be UPDATED:
#
#     certifi:       2019.6.16-py36_1 conda-forge --> 2019.9.11-py36_0 conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.20.0         | 57 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# certifi-2019.9.11    | 147 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '2I3LPFIYIHKOKRDUERZD4BGMBG1MBLDRH51BJVRROQ1LA220' # your Foursquare ID
CLIENT_SECRET = 'FD1DZORVTNISU5UKUBDQBFQIYLKXIVZQJ23IILFJFTNA4A2U' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 100
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: 2I3LPFIYIHKOKRDUERZD4BGMBG1MBLDRH51BJVRROQ1LA220
# CLIENT_SECRET:FD1DZORVTNISU5UKUBDQBFQIYLKXIVZQJ23IILFJFTNA4A2U

# %% [markdown]
# ### Define an instance of the geocoder - Southampton

# %%
address = 'Southampton Central station, Southampton, UK'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 50.9077175 -1.4140262

# %% [markdown]
# ### Search for a specific venue category

# %%
search_query = 'restaurant'
radius = 8000
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %% [markdown]
# ### Define the corresponding URL

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2I3LPFIYIHKOKRDUERZD4BGMBG1MBLDRH51BJVRROQ1LA220&client_secret=FD1DZORVTNISU5UKUBDQBFQIYLKXIVZQJ23IILFJFTNA4A2U&ll=50.9077175,-1.4140262&v=20180604&query=restaurant&radius=8000&limit=100'

# %% [markdown]
# ### Send the GET Request and examine the results

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d9a0769e97dfb002ca05e49'},
#  'response': {'venues': [{'id': '5421f381498ec9dfd2b8af7a',
#     'name': 'Boardwalk Restaurant',
#     'location': {'address': 'Grand Harbour Hotel',
#      'crossStreet': '5 West Quay Rd',
#      'lat': 50.899460258402144,
#      'lng': -1.407923698425293,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.899460258402144,
#        'lng': -1.407923698425293}],
#      'distance': 1014,
#      'postalCode': 'SO14 1AG',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Grand Harbour Hotel (5 West Quay Rd)',
#       'Southampton',
#       'Hampshire',
#       'SO14 1AG',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4d557f409e508cfafade009b',
#     'name': "Bellini's Italian Restaurant & Lounge Bar",
#     'location': {'address': 'Latimer St.',
#      'crossStreet': 'Oxford St.',
#      'lat': 50.89755698952178,
#      'lng': -1.4007924997266352,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.89755698952178,
#        'lng': -1.4007924997266352}],
#      'distance': 1463,
#      'postalCode': 'SO14 3BQ',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Latimer St. (Oxford St.)',
#       'Southampton',
#       'Hampshire',
#       'SO14 3BQ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '5471ed6c498eac135acfef5e',
#     'name': 'IKEA Restaurant',
#     'location': {'address': 'West Quay Road',
#      'lat': 50.90338188125466,
#      'lng': -1.4116343337929713,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.90338188125466,
#        'lng': -1.4116343337929713}],
#      'distance': 511,
#      'postalCode': 'SO15 1GY',
#      'cc': 'GB',
#      'neighborhood': 'City Centre',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['West Quay Road',
#       'Southampton',
#       'Hampshire',
#       'SO15 1GY',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c6941735',
#       'name': 'Scandinavian Restaurant',
#       'pluralName': 'Scandinavian Restaurants',
#       'shortName': 'Scandinavian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/scandinavian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4dee63158877aa0c3cb563a9',
#     'name': 'Orchid Chinese Restaurant',
#     'location': {'address': '9 Commerce road',
#      'lat': 50.908541679380846,
#      'lng': -1.4159488677978105,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.908541679380846,
#        'lng': -1.4159488677978105}],
#      'distance': 163,
#      'postalCode': 'SO1 4 7',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['9 Commerce road',
#       'Southampton',
#       'Hampshire',
#       'SO1 4 7',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '5b7578f933e11800393e1954',
#     'name': 'The Restaurant',
#     'location': {'address': 'Lower Ground Floor',
#      'lat': 50.902386,
#      'lng': -1.399283,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.902386,
#        'lng': -1.399283}],
#      'distance': 1193,
#      'postalCode': 'SO14 1NH',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Lower Ground Floor',
#       'Southampton',
#       'Hampshire',
#       'SO14 1NH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '5a28267e67a9fe1cb715f327',
#     'name': 'Restaurant Transilvania',
#     'location': {'lat': 50.914586,
#      'lng': -1.423566,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.914586,
#        'lng': -1.423566}],
#      'distance': 1016,
#      'postalCode': 'SO15 3FL',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Southampton',
#       'Hampshire',
#       'SO15 3FL',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4d08b748304460fcfeb8d963',
#     'name': 'Ovation Restaurant',
#     'location': {'address': 'The Mayflower Theatre, Commercial Rd',
#      'lat': 50.908915619765274,
#      'lng': -1.4103277998531096,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.908915619765274,
#        'lng': -1.4103277998531096}],
#      'distance': 291,
#      'postalCode': 'SO15 1GE',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['The Mayflower Theatre, Commercial Rd',
#       'Southampton',
#       'Hampshire',
#       'SO15 1GE',
#       'United Kingdom']},
#     'categories': [],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '513246b0e4b02bbf4c99fae3',
#     'name': 'Leelawadee Thai Restaurant',
#     'location': {'address': 'Commercial Road',
#      'lat': 50.908964,
#      'lng': -1.40935,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.908964,
#        'lng': -1.40935}],
#      'distance': 356,
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Commercial Road',
#       'Southampton',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '56b8a828498e29ef0d041238',
#     'name': 'Poppins Restaurant',
#     'location': {'address': '181 High Street',
#      'lat': 50.9023538143245,
#      'lng': -1.4042341045278945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.9023538143245,
#        'lng': -1.4042341045278945}],
#      'distance': 910,
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['181 High Street',
#       'Southampton',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'shortName': 'Diner',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4e0f57deb0fb59de67df89a5',
#     'name': 'Taj Restaurant',
#     'location': {'lat': 50.90866806251364,
#      'lng': -1.4063516538864063,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.90866806251364,
#        'lng': -1.4063516538864063}],
#      'distance': 548,
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Southampton', 'Hampshire', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4db958766a2334682da584b8',
#     'name': 'The Boathouse Restaurant',
#     'location': {'address': 'Hythe Marina',
#      'lat': 50.87301427312694,
#      'lng': -1.4007510934156486,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.87301427312694,
#        'lng': -1.4007510934156486}],
#      'distance': 3974,
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Hythe Marina',
#       'Southampton',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a05',
#       'name': 'English Restaurant',
#       'pluralName': 'English Restaurants',
#       'shortName': 'English',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4f92bddce4b03330a9c616ec',
#     'name': "Christina's Restaurant",
#     'location': {'lat': 50.904109954833984,
#      'lng': -1.4055571556091309,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.904109954833984,
#        'lng': -1.4055571556091309}],
#      'distance': 717,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4d4057a7915a3704f184147f',
#     'name': "Tang's Chinese Restaurant",
#     'location': {'address': '127 Above Bar Street',
#      'crossStreet': 'New Road',
#      'lat': 50.9071291,
#      'lng': -1.404462,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.9071291,
#        'lng': -1.404462}],
#      'distance': 674,
#      'postalCode': 'SO14 7FH',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['127 Above Bar Street (New Road)',
#       'Southampton',
#       'Hampshire',
#       'SO14 7FH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '54b5123c498e16364a32cd80',
#     'name': '88 chinese restaurant',
#     'location': {'lat': 50.911926,
#      'lng': -1.403879,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.911926,
#        'lng': -1.403879}],
#      'distance': 852,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '52af3a7c3cf9994f4e043bed',
#       'name': 'Cantonese Restaurant',
#       'pluralName': 'Cantonese Restaurants',
#       'shortName': 'Cantonese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '5b72e3e2a2c00b002c1cfda8',
#     'name': 'Beity Lebanese Restaurant',
#     'location': {'address': '123-124 High Street',
#      'lat': 50.90241796892794,
#      'lng': -1.4042383432388303,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.90241796892794,
#        'lng': -1.4042383432388303}],
#      'distance': 905,
#      'postalCode': 'SO14 2DJ',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['123-124 High Street',
#       'Southampton',
#       'Hampshire',
#       'SO14 2DJ',
#       'United Kingdom']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1cd',
#       'name': 'Lebanese Restaurant',
#       'pluralName': 'Lebanese Restaurants',
#       'shortName': 'Lebanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '570b464c498e9c41fef9e56b',
#     'name': 'Hotel Restaurant',
#     'location': {'lat': 50.911256123954594,
#      'lng': -1.4013774746415846,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.911256123954594,
#        'lng': -1.4013774746415846}],
#      'distance': 971,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '5b522d7cdd70c5003958f86e',
#     'name': 'Shire Restaurant',
#     'location': {'lat': 50.91289,
#      'lng': -1.3998874,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.91289,
#        'lng': -1.3998874}],
#      'distance': 1147,
#      'postalCode': 'SO14 0JD',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Southampton',
#       'Hampshire',
#       'SO14 0JD',
#       'United Kingdom']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a04',
#       'name': 'Polish Restaurant',
#       'pluralName': 'Polish Restaurants',
#       'shortName': 'Polish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4e73a3dcd4c0c01bf848ddcd',
#     'name': 'Simons at Oxfords Wine Bar Restaurant',
#     'location': {'address': '35 Oxford Street',
#      'lat': 50.897969680808366,
#      'lng': -1.3974197466707259,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.897969680808366,
#        'lng': -1.3974197466707259}],
#      'distance': 1592,
#      'postalCode': 'SO14 3DS',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['35 Oxford Street',
#       'Southampton',
#       'Hampshire',
#       'SO14 3DS',
#       'United Kingdom']},
#     'categories': [{'id': '4d4b7105d754a06374d81259',
#       'name': 'Food',
#       'pluralName': 'Food',
#       'shortName': 'Food',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '518513c4498ee03b38df34b6',
#     'name': 'Casanova Italian Restaurant',
#     'location': {'address': '85-87 Queensway',
#      'lat': 50.90219323186157,
#      'lng': -1.4008783739775905,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.90219323186157,
#        'lng': -1.4008783739775905}],
#      'distance': 1109,
#      'postalCode': 'SO14 3HJ',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['85-87 Queensway',
#       'Southampton',
#       'Hampshire',
#       'SO14 3HJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4ea1f18dbe7ba4918e0aca4e',
#     'name': "Sam's Bar And Restaurant",
#     'location': {'lat': 50.901869261685924,
#      'lng': -1.4002230862490919,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.901869261685924,
#        'lng': -1.4002230862490919}],
#      'distance': 1167,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4ccc805cc0378cfa0e248748',
#     'name': 'Elias Restaurant',
#     'location': {'address': 'Canal Walk',
#      'lat': 50.90132824854898,
#      'lng': -1.4011990516323625,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.90132824854898,
#        'lng': -1.4011990516323625}],
#      'distance': 1147,
#      'postalCode': 'SO1 4 3',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Canal Walk',
#       'Southampton',
#       'Hampshire',
#       'SO1 4 3',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10e941735',
#       'name': 'Greek Restaurant',
#       'pluralName': 'Greek Restaurants',
#       'shortName': 'Greek',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4b2a8febf964a5206aab24e3',
#     'name': 'The Chambeli Restaurant',
#     'location': {'address': 'Southampton Rd.',
#      'lat': 50.91762163308047,
#      'lng': -1.4084957989641234,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.91762163308047,
#        'lng': -1.4084957989641234}],
#      'distance': 1168,
#      'cc': 'GB',
#      'city': 'London',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Southampton Rd.', 'London', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4c9539bef244b1f7bed8291d',
#     'name': "George's Restaurant",
#     'location': {'lat': 50.8993188315396,
#      'lng': -1.404838808484277,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.8993188315396,
#        'lng': -1.404838808484277}],
#      'distance': 1135,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10e941735',
#       'name': 'Greek Restaurant',
#       'pluralName': 'Greek Restaurants',
#       'shortName': 'Greek',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '522b5340498ea7a6b6fc4aa9',
#     'name': "Christina's Restaurant",
#     'location': {'lat': 50.901725,
#      'lng': -1.399647,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.901725,
#        'lng': -1.399647}],
#      'distance': 1209,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '56ae11ba498ecac5674a5728',
#     'name': 'The Restaurant at HASKINS',
#     'location': {'address': 'Mansbridge Road',
#      'lat': 50.93554704101988,
#      'lng': -1.3553450146203199,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.93554704101988,
#        'lng': -1.3553450146203199}],
#      'distance': 5153,
#      'postalCode': 'SO18 3HW',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Mansbridge Road',
#       'Southampton',
#       'Hampshire',
#       'SO18 3HW',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '57cffd0f498e98e8575aaef5',
#     'name': 'Zen Japanese Restaurant',
#     'location': {'address': '42 High Street',
#      'lat': 50.8993925,
#      'lng': -1.4035106,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.8993925,
#        'lng': -1.4035106}],
#      'distance': 1184,
#      'postalCode': 'SO14 2NS',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['42 High Street',
#       'Southampton',
#       'Hampshire',
#       'SO14 2NS',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '54d67028498ee595408d325c',
#     'name': 'Balkh Afgan Restaurant',
#     'location': {'lat': 50.906039,
#      'lng': -1.396637,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.906039,
#        'lng': -1.396637}],
#      'distance': 1234,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '503288ae91d4c4b30a586d67',
#       'name': 'Afghan Restaurant',
#       'pluralName': 'Afghan Restaurants',
#       'shortName': 'Afghan',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/afghan_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4f0c795de4b0c67b44f0153a',
#     'name': 'Shwan Restaurant & Takeaway',
#     'location': {'address': '113 Derby Road',
#      'lat': 50.911501527496746,
#      'lng': -1.3936043664237254,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.911501527496746,
#        'lng': -1.3936043664237254}],
#      'distance': 1494,
#      'postalCode': 'SO14 0DR',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['113 Derby Road',
#       'Southampton',
#       'Hampshire',
#       'SO14 0DR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4e92d2f49adf18f8829cbe18',
#     'name': 'kisna',
#     'location': {'lat': 50.9096691781579,
#      'lng': -1.4132173455855523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.9096691781579,
#        'lng': -1.4132173455855523}],
#      'distance': 224,
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Southampton', 'Hampshire', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4b99705cf964a520977b35e3',
#     'name': 'Lupa Restaurant',
#     'location': {'address': '23-124 High Street, Below Bar',
#      'lat': 50.89929932913499,
#      'lng': -1.4037707667949293,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.89929932913499,
#        'lng': -1.4037707667949293}],
#      'distance': 1181,
#      'postalCode': 'SO14 2AA',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['23-124 High Street, Below Bar',
#       'Southampton',
#       'Hampshire',
#       'SO14 2AA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4bc5cb52ccbcef3bd5f3e6d2',
#     'name': "Jury's Inn",
#     'location': {'address': '1 Charlotte Pl',
#      'lat': 50.91070195823153,
#      'lng': -1.4014906257612931,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.91070195823153,
#        'lng': -1.4014906257612931}],
#      'distance': 940,
#      'postalCode': 'SO14 0TB',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1 Charlotte Pl',
#       'Southampton',
#       'Hampshire',
#       'SO14 0TB',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1fa931735',
#       'name': 'Hotel',
#       'pluralName': 'Hotels',
#       'shortName': 'Hotel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4c69840735d3be9a17861f06',
#     'name': 'Posh Indian Restaurant',
#     'location': {'address': '1 Queensway',
#      'lat': 50.8975589545427,
#      'lng': -1.400779868070436,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.8975589545427,
#        'lng': -1.400779868070436}],
#      'distance': 1464,
#      'postalCode': 'SO14 3AQ',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['1 Queensway',
#       'Southampton',
#       'Hampshire',
#       'SO14 3AQ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4dc2fe57ae608779d0fde30c',
#     'name': 'Aspire Restaurant',
#     'location': {'address': 'Southampton City College',
#      'lat': 50.903397,
#      'lng': -1.394277,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.903397,
#        'lng': -1.394277}],
#      'distance': 1467,
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Southampton City College',
#       'Southampton',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '50ca02c1245f2d4aa8c2b90d',
#     'name': 'The Restaurant',
#     'location': {'address': 'Bracken Pl',
#      'crossStreet': 'Hilton Southampton',
#      'lat': 50.9530193172855,
#      'lng': -1.4019485916844447,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.9530193172855,
#        'lng': -1.4019485916844447}],
#      'distance': 5113,
#      'postalCode': 'SO16 3RB',
#      'cc': 'GB',
#      'city': 'Chilworth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Bracken Pl (Hilton Southampton)',
#       'Chilworth',
#       'Hampshire',
#       'SO16 3RB',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4b7c4fcdf964a520958b2fe3',
#     'name': 'Ceno Restaurant',
#     'location': {'address': '119 Highfield Lane',
#      'lat': 50.92761612838817,
#      'lng': -1.3916179964930693,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.92761612838817,
#        'lng': -1.3916179964930693}],
#      'distance': 2716,
#      'postalCode': 'SO17 1AQ',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['119 Highfield Lane',
#       'Southampton',
#       'Hampshire',
#       'SO17 1AQ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'shortName': 'Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '5772ab6b498e80d8dcee6790',
#     'name': 'Thyme Restaurant',
#     'location': {'lat': 50.948523,
#      'lng': -1.364439,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.948523,
#        'lng': -1.364439}],
#      'distance': 5721,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '5a74820e1ffe971ebc0c31e8',
#     'name': 'Dahlia Restaurant',
#     'location': {'lat': 50.921105,
#      'lng': -1.431816,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.921105,
#        'lng': -1.431816}],
#      'distance': 1944,
#      'postalCode': 'S O15',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Southampton',
#       'Hampshire',
#       'S O15',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '5384f6a2498ec1985aa33311',
#     'name': 'Pilgrim House Chinese Restaurant',
#     'location': {'address': 'Canute Rd.',
#      'lat': 50.896879,
#      'lng': -1.393762,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.896879,
#        'lng': -1.393762}],
#      'distance': 1865,
#      'postalCode': 'SO14 3FJ',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Canute Rd.',
#       'Southampton',
#       'Hampshire',
#       'SO14 3FJ',
#       'United Kingdom']},
#     'categories': [],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4e2a764cd22d3f83c8847e76',
#     'name': 'Ventura Bay Tree Restaurant',
#     'location': {'lat': 50.892814230918624,
#      'lng': -1.399619812324583,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.892814230918624,
#        'lng': -1.399619812324583}],
#      'distance': 1943,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4e50d390d22daf51d2899a54',
#     'name': "Piggy's Coffee Shop & Restaurant",
#     'location': {'address': '26 Victoria Rd',
#      'crossStreet': 'Woolston',
#      'lat': 50.89724032473285,
#      'lng': -1.3798021451729332,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.89724032473285,
#        'lng': -1.3798021451729332}],
#      'distance': 2670,
#      'postalCode': 'SO19 9DX',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['26 Victoria Rd (Woolston)',
#       'Southampton',
#       'Hampshire',
#       'SO19 9DX',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1e0931735',
#       'name': 'Coffee Shop',
#       'pluralName': 'Coffee Shops',
#       'shortName': 'Coffee Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '520b5b5411d214f5f28b7d85',
#     'name': 'Sainsburys Restaurant',
#     'location': {'lat': 50.92338081601199,
#      'lng': -1.4343930962086517,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.92338081601199,
#        'lng': -1.4343930962086517}],
#      'distance': 2254,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4dd4136b18384691b9b86fd0',
#     'name': 'Taps Restaurant',
#     'location': {'address': 'Shamrock Quay',
#      'lat': 50.910118,
#      'lng': -1.381725,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.910118,
#        'lng': -1.381725}],
#      'distance': 2282,
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Shamrock Quay',
#       'Southampton',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4dc135180f2c14a8450cde21',
#     'name': 'Number 10',
#     'location': {'address': '10 Bedford Place',
#      'crossStreet': 'Parallel to London Road',
#      'lat': 50.91166685734257,
#      'lng': -1.4057269839573785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.91166685734257,
#        'lng': -1.4057269839573785}],
#      'distance': 729,
#      'postalCode': 'SO15 2DB',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['10 Bedford Place (Parallel to London Road)',
#       'Southampton',
#       'Hampshire',
#       'SO15 2DB',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4bae6b43f964a520e2af3be3',
#     'name': 'Special Thai Restaurant',
#     'location': {'lat': 50.982491,
#      'lng': -1.382201,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.982491,
#        'lng': -1.382201}],
#      'distance': 8617,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4b900cbbf964a520737233e3',
#     'name': 'Oxfords',
#     'location': {'address': '35-36 Oxford St.',
#      'lat': 50.898041,
#      'lng': -1.397369,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.898041,
#        'lng': -1.397369}],
#      'distance': 1589,
#      'postalCode': 'SO15 3DS',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['35-36 Oxford St.',
#       'Southampton',
#       'Hampshire',
#       'SO15 3DS',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d155941735',
#       'name': 'Gastropub',
#       'pluralName': 'Gastropubs',
#       'shortName': 'Gastropub',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/gastropub_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4bf82aeb5efe2d7f78466a34',
#     'name': 'Jehangir Indian & Bangladeshi Restaurant',
#     'location': {'address': '347 Winchester Rd.',
#      'lat': 50.93429216842349,
#      'lng': -1.4188134822202523,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.93429216842349,
#        'lng': -1.4188134822202523}],
#      'distance': 2977,
#      'postalCode': 'SO16 7DJ',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['347 Winchester Rd.',
#       'Southampton',
#       'Hampshire',
#       'SO16 7DJ',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4cb0b60acbab236acbe2a273',
#     'name': 'The King and I',
#     'location': {'address': '134 High St',
#      'lat': 50.89991516999714,
#      'lng': -1.4036255552849566,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.89991516999714,
#        'lng': -1.4036255552849566}],
#      'distance': 1134,
#      'postalCode': 'SO14 2BR',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['134 High St',
#       'Southampton',
#       'Hampshire',
#       'SO14 2BR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'shortName': 'Thai',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '50850171e4b0290494560b4f',
#     'name': 'The Grove Restaurant',
#     'location': {'lat': 50.925086,
#      'lng': -1.446289,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.925086,
#        'lng': -1.446289}],
#      'distance': 2977,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '5072abefe4b0e1b65f24d189',
#     'name': "Zara's Restaurant",
#     'location': {'address': 'Level E, Coxford Road',
#      'lat': 50.93548756087531,
#      'lng': -1.4348342295816454,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.93548756087531,
#        'lng': -1.4348342295816454}],
#      'distance': 3418,
#      'postalCode': 'SO16 5YA',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Level E, Coxford Road',
#       'Southampton',
#       'Hampshire',
#       'SO16 5YA',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False},
#    {'id': '4fbd27a1e4b00902117e2cca',
#     'name': 'Merchants Blue Moon',
#     'location': {'address': 'Ocean Village',
#      'lat': 50.897308341259766,
#      'lng': -1.3918743373658355,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.897308341259766,
#        'lng': -1.3918743373658355}],
#      'distance': 1939,
#      'postalCode': 'SO14 3TN',
#      'cc': 'GB',
#      'city': 'Southampton',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Ocean Village',
#       'Southampton',
#       'Hampshire',
#       'SO14 3TN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1cc941735',
#       'name': 'Steakhouse',
#       'pluralName': 'Steakhouses',
#       'shortName': 'Steakhouse',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570375529',
#     'hasPerk': False}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                                       name  \
# 0  5421f381498ec9dfd2b8af7a                       Boardwalk Restaurant
# 1  4d557f409e508cfafade009b  Bellini's Italian Restaurant & Lounge Bar
# 2  5471ed6c498eac135acfef5e                            IKEA Restaurant
# 3  4dee63158877aa0c3cb563a9                  Orchid Chinese Restaurant
# 4  5b7578f933e11800393e1954                             The Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1570375529    False
# 1  [{'id': '4bf58dd8d48988d110941735', 'name': 'I...  v-1570375529    False
# 2  [{'id': '4bf58dd8d48988d1c6941735', 'name': 'S...  v-1570375529    False
# 3  [{'id': '4bf58dd8d48988d145941735', 'name': 'C...  v-1570375529    False
# 4  [{'id': '4bf58dd8d48988d1c4941735', 'name': 'R...  v-1570375529    False
#
#       location.address location.crossStreet  location.lat  location.lng  \
# 0  Grand Harbour Hotel       5 West Quay Rd     50.899460     -1.407924
# 1          Latimer St.           Oxford St.     50.897557     -1.400792
# 2       West Quay Road                  NaN     50.903382     -1.411634
# 3      9 Commerce road                  NaN     50.908542     -1.415949
# 4   Lower Ground Floor                  NaN     50.902386     -1.399283
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 50.89946025840214...               1014
# 1  [{'label': 'display', 'lat': 50.89755698952178...               1463
# 2  [{'label': 'display', 'lat': 50.90338188125466...                511
# 3  [{'label': 'display', 'lat': 50.90854167938084...                163
# 4  [{'label': 'display', 'lat': 50.902386, 'lng':...               1193
#
#   location.postalCode location.cc location.city location.state  \
# 0            SO14 1AG          GB   Southampton      Hampshire
# 1            SO14 3BQ          GB   Southampton      Hampshire
# 2            SO15 1GY          GB   Southampton      Hampshire
# 3             SO1 4 7          GB   Southampton      Hampshire
# 4            SO14 1NH          GB   Southampton      Hampshire
#
#   location.country                          location.formattedAddress  \
# 0   United Kingdom  [Grand Harbour Hotel (5 West Quay Rd), Southam...
# 1   United Kingdom  [Latimer St. (Oxford St.), Southampton, Hampsh...
# 2   United Kingdom  [West Quay Road, Southampton, Hampshire, SO15 ...
# 3   United Kingdom  [9 Commerce road, Southampton, Hampshire, SO1 ...
# 4   United Kingdom  [Lower Ground Floor, Southampton, Hampshire, S...
#
#   location.neighborhood
# 0                   NaN
# 1                   NaN
# 2           City Centre
# 3                   NaN
# 4                   NaN

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                          name                 categories  \
# 0                        Boardwalk Restaurant                 Restaurant
# 1   Bellini's Italian Restaurant & Lounge Bar         Italian Restaurant
# 2                             IKEA Restaurant    Scandinavian Restaurant
# 3                   Orchid Chinese Restaurant         Chinese Restaurant
# 4                              The Restaurant                 Restaurant
# 5                     Restaurant Transilvania                 Restaurant
# 6                          Ovation Restaurant                       None
# 7                  Leelawadee Thai Restaurant            Thai Restaurant
# 8                          Poppins Restaurant                      Diner
# 9                              Taj Restaurant          Indian Restaurant
# 10                   The Boathouse Restaurant         English Restaurant
# 11                     Christina's Restaurant                 Restaurant
# 12                  Tang's Chinese Restaurant         Chinese Restaurant
# 13                      88 chinese restaurant       Cantonese Restaurant
# 14                  Beity Lebanese Restaurant        Lebanese Restaurant
# 15                           Hotel Restaurant             Breakfast Spot
# 16                           Shire Restaurant          Polish Restaurant
# 17      Simons at Oxfords Wine Bar Restaurant                       Food
# 18                Casanova Italian Restaurant         Italian Restaurant
# 19                   Sam's Bar And Restaurant             Breakfast Spot
# 20                           Elias Restaurant           Greek Restaurant
# 21                    The Chambeli Restaurant                 Restaurant
# 22                        George's Restaurant           Greek Restaurant
# 23                     Christina's Restaurant                       Café
# 24                  The Restaurant at HASKINS                       Café
# 25                    Zen Japanese Restaurant        Japanese Restaurant
# 26                     Balkh Afgan Restaurant          Afghan Restaurant
# 27                Shwan Restaurant & Takeaway  Middle Eastern Restaurant
# 28                                      kisna          Indian Restaurant
# 29                            Lupa Restaurant         Italian Restaurant
# 30                                 Jury's Inn                      Hotel
# 31                     Posh Indian Restaurant          Indian Restaurant
# 32                          Aspire Restaurant                 Restaurant
# 33                             The Restaurant                 Restaurant
# 34                            Ceno Restaurant                        Bar
# 35                           Thyme Restaurant                 Restaurant
# 36                          Dahlia Restaurant                 Restaurant
# 37           Pilgrim House Chinese Restaurant                       None
# 38                Ventura Bay Tree Restaurant                 Restaurant
# 39           Piggy's Coffee Shop & Restaurant                Coffee Shop
# 40                      Sainsburys Restaurant                       Café
# 41                            Taps Restaurant                 Restaurant
# 42                                  Number 10   Mediterranean Restaurant
# 43                    Special Thai Restaurant            Thai Restaurant
# 44                                    Oxfords                  Gastropub
# 45   Jehangir Indian & Bangladeshi Restaurant          Indian Restaurant
# 46                             The King and I            Thai Restaurant
# 47                       The Grove Restaurant                 Restaurant
# 48                          Zara's Restaurant                       Café
# 49                        Merchants Blue Moon                 Steakhouse
#
#                                  address              crossStreet        lat  \
# 0                    Grand Harbour Hotel           5 West Quay Rd  50.899460
# 1                            Latimer St.               Oxford St.  50.897557
# 2                         West Quay Road                      NaN  50.903382
# 3                        9 Commerce road                      NaN  50.908542
# 4                     Lower Ground Floor                      NaN  50.902386
# 5                                    NaN                      NaN  50.914586
# 6   The Mayflower Theatre, Commercial Rd                      NaN  50.908916
# 7                        Commercial Road                      NaN  50.908964
# 8                        181 High Street                      NaN  50.902354
# 9                                    NaN                      NaN  50.908668
# 10                          Hythe Marina                      NaN  50.873014
# 11                                   NaN                      NaN  50.904110
# 12                  127 Above Bar Street                 New Road  50.907129
# 13                                   NaN                      NaN  50.911926
# 14                   123-124 High Street                      NaN  50.902418
# 15                                   NaN                      NaN  50.911256
# 16                                   NaN                      NaN  50.912890
# 17                      35 Oxford Street                      NaN  50.897970
# 18                       85-87 Queensway                      NaN  50.902193
# 19                                   NaN                      NaN  50.901869
# 20                            Canal Walk                      NaN  50.901328
# 21                       Southampton Rd.                      NaN  50.917622
# 22                                   NaN                      NaN  50.899319
# 23                                   NaN                      NaN  50.901725
# 24                       Mansbridge Road                      NaN  50.935547
# 25                        42 High Street                      NaN  50.899392
# 26                                   NaN                      NaN  50.906039
# 27                        113 Derby Road                      NaN  50.911502
# 28                                   NaN                      NaN  50.909669
# 29         23-124 High Street, Below Bar                      NaN  50.899299
# 30                        1 Charlotte Pl                      NaN  50.910702
# 31                           1 Queensway                      NaN  50.897559
# 32              Southampton City College                      NaN  50.903397
# 33                            Bracken Pl       Hilton Southampton  50.953019
# 34                    119 Highfield Lane                      NaN  50.927616
# 35                                   NaN                      NaN  50.948523
# 36                                   NaN                      NaN  50.921105
# 37                            Canute Rd.                      NaN  50.896879
# 38                                   NaN                      NaN  50.892814
# 39                        26 Victoria Rd                 Woolston  50.897240
# 40                                   NaN                      NaN  50.923381
# 41                         Shamrock Quay                      NaN  50.910118
# 42                      10 Bedford Place  Parallel to London Road  50.911667
# 43                                   NaN                      NaN  50.982491
# 44                      35-36 Oxford St.                      NaN  50.898041
# 45                    347 Winchester Rd.                      NaN  50.934292
# 46                           134 High St                      NaN  50.899915
# 47                                   NaN                      NaN  50.925086
# 48                 Level E, Coxford Road                      NaN  50.935488
# 49                         Ocean Village                      NaN  50.897308
#
#          lng                                     labeledLatLngs  distance  \
# 0  -1.407924  [{'label': 'display', 'lat': 50.89946025840214...      1014
# 1  -1.400792  [{'label': 'display', 'lat': 50.89755698952178...      1463
# 2  -1.411634  [{'label': 'display', 'lat': 50.90338188125466...       511
# 3  -1.415949  [{'label': 'display', 'lat': 50.90854167938084...       163
# 4  -1.399283  [{'label': 'display', 'lat': 50.902386, 'lng':...      1193
# 5  -1.423566  [{'label': 'display', 'lat': 50.914586, 'lng':...      1016
# 6  -1.410328  [{'label': 'display', 'lat': 50.90891561976527...       291
# 7  -1.409350  [{'label': 'display', 'lat': 50.908964, 'lng':...       356
# 8  -1.404234  [{'label': 'display', 'lat': 50.9023538143245,...       910
# 9  -1.406352  [{'label': 'display', 'lat': 50.90866806251364...       548
# 10 -1.400751  [{'label': 'display', 'lat': 50.87301427312694...      3974
# 11 -1.405557  [{'label': 'display', 'lat': 50.90410995483398...       717
# 12 -1.404462  [{'label': 'display', 'lat': 50.9071291, 'lng'...       674
# 13 -1.403879  [{'label': 'display', 'lat': 50.911926, 'lng':...       852
# 14 -1.404238  [{'label': 'display', 'lat': 50.90241796892794...       905
# 15 -1.401377  [{'label': 'display', 'lat': 50.91125612395459...       971
# 16 -1.399887  [{'label': 'display', 'lat': 50.91289, 'lng': ...      1147
# 17 -1.397420  [{'label': 'display', 'lat': 50.89796968080836...      1592
# 18 -1.400878  [{'label': 'display', 'lat': 50.90219323186157...      1109
# 19 -1.400223  [{'label': 'display', 'lat': 50.90186926168592...      1167
# 20 -1.401199  [{'label': 'display', 'lat': 50.90132824854898...      1147
# 21 -1.408496  [{'label': 'display', 'lat': 50.91762163308047...      1168
# 22 -1.404839  [{'label': 'display', 'lat': 50.8993188315396,...      1135
# 23 -1.399647  [{'label': 'display', 'lat': 50.901725, 'lng':...      1209
# 24 -1.355345  [{'label': 'display', 'lat': 50.93554704101988...      5153
# 25 -1.403511  [{'label': 'display', 'lat': 50.8993925, 'lng'...      1184
# 26 -1.396637  [{'label': 'display', 'lat': 50.906039, 'lng':...      1234
# 27 -1.393604  [{'label': 'display', 'lat': 50.91150152749674...      1494
# 28 -1.413217  [{'label': 'display', 'lat': 50.9096691781579,...       224
# 29 -1.403771  [{'label': 'display', 'lat': 50.89929932913499...      1181
# 30 -1.401491  [{'label': 'display', 'lat': 50.91070195823153...       940
# 31 -1.400780  [{'label': 'display', 'lat': 50.8975589545427,...      1464
# 32 -1.394277  [{'label': 'display', 'lat': 50.903397, 'lng':...      1467
# 33 -1.401949  [{'label': 'display', 'lat': 50.9530193172855,...      5113
# 34 -1.391618  [{'label': 'display', 'lat': 50.92761612838817...      2716
# 35 -1.364439  [{'label': 'display', 'lat': 50.948523, 'lng':...      5721
# 36 -1.431816  [{'label': 'display', 'lat': 50.921105, 'lng':...      1944
# 37 -1.393762  [{'label': 'display', 'lat': 50.896879, 'lng':...      1865
# 38 -1.399620  [{'label': 'display', 'lat': 50.89281423091862...      1943
# 39 -1.379802  [{'label': 'display', 'lat': 50.89724032473285...      2670
# 40 -1.434393  [{'label': 'display', 'lat': 50.92338081601199...      2254
# 41 -1.381725  [{'label': 'display', 'lat': 50.910118, 'lng':...      2282
# 42 -1.405727  [{'label': 'display', 'lat': 50.91166685734257...       729
# 43 -1.382201  [{'label': 'display', 'lat': 50.982491, 'lng':...      8617
# 44 -1.397369  [{'label': 'display', 'lat': 50.898041, 'lng':...      1589
# 45 -1.418813  [{'label': 'display', 'lat': 50.93429216842349...      2977
# 46 -1.403626  [{'label': 'display', 'lat': 50.89991516999714...      1134
# 47 -1.446289  [{'label': 'display', 'lat': 50.925086, 'lng':...      2977
# 48 -1.434834  [{'label': 'display', 'lat': 50.93548756087531...      3418
# 49 -1.391874  [{'label': 'display', 'lat': 50.89730834125976...      1939
#
#    postalCode  cc         city      state         country  \
# 0    SO14 1AG  GB  Southampton  Hampshire  United Kingdom
# 1    SO14 3BQ  GB  Southampton  Hampshire  United Kingdom
# 2    SO15 1GY  GB  Southampton  Hampshire  United Kingdom
# 3     SO1 4 7  GB  Southampton  Hampshire  United Kingdom
# 4    SO14 1NH  GB  Southampton  Hampshire  United Kingdom
# 5    SO15 3FL  GB  Southampton  Hampshire  United Kingdom
# 6    SO15 1GE  GB  Southampton  Hampshire  United Kingdom
# 7         NaN  GB  Southampton  Hampshire  United Kingdom
# 8         NaN  GB  Southampton  Hampshire  United Kingdom
# 9         NaN  GB  Southampton  Hampshire  United Kingdom
# 10        NaN  GB  Southampton  Hampshire  United Kingdom
# 11        NaN  GB          NaN        NaN  United Kingdom
# 12   SO14 7FH  GB  Southampton  Hampshire  United Kingdom
# 13        NaN  GB          NaN        NaN  United Kingdom
# 14   SO14 2DJ  GB  Southampton  Hampshire  United Kingdom
# 15        NaN  GB          NaN        NaN  United Kingdom
# 16   SO14 0JD  GB  Southampton  Hampshire  United Kingdom
# 17   SO14 3DS  GB  Southampton  Hampshire  United Kingdom
# 18   SO14 3HJ  GB  Southampton  Hampshire  United Kingdom
# 19        NaN  GB          NaN        NaN  United Kingdom
# 20    SO1 4 3  GB  Southampton  Hampshire  United Kingdom
# 21        NaN  GB       London        NaN  United Kingdom
# 22        NaN  GB          NaN        NaN  United Kingdom
# 23        NaN  GB          NaN        NaN  United Kingdom
# 24   SO18 3HW  GB  Southampton  Hampshire  United Kingdom
# 25   SO14 2NS  GB  Southampton  Hampshire  United Kingdom
# 26        NaN  GB          NaN        NaN  United Kingdom
# 27   SO14 0DR  GB  Southampton  Hampshire  United Kingdom
# 28        NaN  GB  Southampton  Hampshire  United Kingdom
# 29   SO14 2AA  GB  Southampton  Hampshire  United Kingdom
# 30   SO14 0TB  GB  Southampton  Hampshire  United Kingdom
# 31   SO14 3AQ  GB  Southampton  Hampshire  United Kingdom
# 32        NaN  GB  Southampton  Hampshire  United Kingdom
# 33   SO16 3RB  GB    Chilworth  Hampshire  United Kingdom
# 34   SO17 1AQ  GB  Southampton  Hampshire  United Kingdom
# 35        NaN  GB          NaN        NaN  United Kingdom
# 36      S O15  GB  Southampton  Hampshire  United Kingdom
# 37   SO14 3FJ  GB  Southampton  Hampshire  United Kingdom
# 38        NaN  GB          NaN        NaN  United Kingdom
# 39   SO19 9DX  GB  Southampton  Hampshire  United Kingdom
# 40        NaN  GB          NaN        NaN  United Kingdom
# 41        NaN  GB  Southampton  Hampshire  United Kingdom
# 42   SO15 2DB  GB  Southampton  Hampshire  United Kingdom
# 43        NaN  GB          NaN        NaN  United Kingdom
# 44   SO15 3DS  GB  Southampton  Hampshire  United Kingdom
# 45   SO16 7DJ  GB  Southampton  Hampshire  United Kingdom
# 46   SO14 2BR  GB  Southampton  Hampshire  United Kingdom
# 47        NaN  GB          NaN        NaN  United Kingdom
# 48   SO16 5YA  GB  Southampton  Hampshire  United Kingdom
# 49   SO14 3TN  GB  Southampton  Hampshire  United Kingdom
#
#                                      formattedAddress neighborhood  \
# 0   [Grand Harbour Hotel (5 West Quay Rd), Southam...          NaN
# 1   [Latimer St. (Oxford St.), Southampton, Hampsh...          NaN
# 2   [West Quay Road, Southampton, Hampshire, SO15 ...  City Centre
# 3   [9 Commerce road, Southampton, Hampshire, SO1 ...          NaN
# 4   [Lower Ground Floor, Southampton, Hampshire, S...          NaN
# 5   [Southampton, Hampshire, SO15 3FL, United King...          NaN
# 6   [The Mayflower Theatre, Commercial Rd, Southam...          NaN
# 7   [Commercial Road, Southampton, Hampshire, Unit...          NaN
# 8   [181 High Street, Southampton, Hampshire, Unit...          NaN
# 9            [Southampton, Hampshire, United Kingdom]          NaN
# 10  [Hythe Marina, Southampton, Hampshire, United ...          NaN
# 11                                   [United Kingdom]          NaN
# 12  [127 Above Bar Street (New Road), Southampton,...          NaN
# 13                                   [United Kingdom]          NaN
# 14  [123-124 High Street, Southampton, Hampshire, ...          NaN
# 15                                   [United Kingdom]          NaN
# 16  [Southampton, Hampshire, SO14 0JD, United King...          NaN
# 17  [35 Oxford Street, Southampton, Hampshire, SO1...          NaN
# 18  [85-87 Queensway, Southampton, Hampshire, SO14...          NaN
# 19                                   [United Kingdom]          NaN
# 20  [Canal Walk, Southampton, Hampshire, SO1 4 3, ...          NaN
# 21          [Southampton Rd., London, United Kingdom]          NaN
# 22                                   [United Kingdom]          NaN
# 23                                   [United Kingdom]          NaN
# 24  [Mansbridge Road, Southampton, Hampshire, SO18...          NaN
# 25  [42 High Street, Southampton, Hampshire, SO14 ...          NaN
# 26                                   [United Kingdom]          NaN
# 27  [113 Derby Road, Southampton, Hampshire, SO14 ...          NaN
# 28           [Southampton, Hampshire, United Kingdom]          NaN
# 29  [23-124 High Street, Below Bar, Southampton, H...          NaN
# 30  [1 Charlotte Pl, Southampton, Hampshire, SO14 ...          NaN
# 31  [1 Queensway, Southampton, Hampshire, SO14 3AQ...          NaN
# 32  [Southampton City College, Southampton, Hampsh...          NaN
# 33  [Bracken Pl (Hilton Southampton), Chilworth, H...          NaN
# 34  [119 Highfield Lane, Southampton, Hampshire, S...          NaN
# 35                                   [United Kingdom]          NaN
# 36    [Southampton, Hampshire, S O15, United Kingdom]          NaN
# 37  [Canute Rd., Southampton, Hampshire, SO14 3FJ,...          NaN
# 38                                   [United Kingdom]          NaN
# 39  [26 Victoria Rd (Woolston), Southampton, Hamps...          NaN
# 40                                   [United Kingdom]          NaN
# 41  [Shamrock Quay, Southampton, Hampshire, United...          NaN
# 42  [10 Bedford Place (Parallel to London Road), S...          NaN
# 43                                   [United Kingdom]          NaN
# 44  [35-36 Oxford St., Southampton, Hampshire, SO1...          NaN
# 45  [347 Winchester Rd., Southampton, Hampshire, S...          NaN
# 46  [134 High St, Southampton, Hampshire, SO14 2BR...          NaN
# 47                                   [United Kingdom]          NaN
# 48  [Level E, Coxford Road, Southampton, Hampshire...          NaN
# 49  [Ocean Village, Southampton, Hampshire, SO14 3...          NaN
#
#                           id
# 0   5421f381498ec9dfd2b8af7a
# 1   4d557f409e508cfafade009b
# 2   5471ed6c498eac135acfef5e
# 3   4dee63158877aa0c3cb563a9
# 4   5b7578f933e11800393e1954
# 5   5a28267e67a9fe1cb715f327
# 6   4d08b748304460fcfeb8d963
# 7   513246b0e4b02bbf4c99fae3
# 8   56b8a828498e29ef0d041238
# 9   4e0f57deb0fb59de67df89a5
# 10  4db958766a2334682da584b8
# 11  4f92bddce4b03330a9c616ec
# 12  4d4057a7915a3704f184147f
# 13  54b5123c498e16364a32cd80
# 14  5b72e3e2a2c00b002c1cfda8
# 15  570b464c498e9c41fef9e56b
# 16  5b522d7cdd70c5003958f86e
# 17  4e73a3dcd4c0c01bf848ddcd
# 18  518513c4498ee03b38df34b6
# 19  4ea1f18dbe7ba4918e0aca4e
# 20  4ccc805cc0378cfa0e248748
# 21  4b2a8febf964a5206aab24e3
# 22  4c9539bef244b1f7bed8291d
# 23  522b5340498ea7a6b6fc4aa9
# 24  56ae11ba498ecac5674a5728
# 25  57cffd0f498e98e8575aaef5
# 26  54d67028498ee595408d325c
# 27  4f0c795de4b0c67b44f0153a
# 28  4e92d2f49adf18f8829cbe18
# 29  4b99705cf964a520977b35e3
# 30  4bc5cb52ccbcef3bd5f3e6d2
# 31  4c69840735d3be9a17861f06
# 32  4dc2fe57ae608779d0fde30c
# 33  50ca02c1245f2d4aa8c2b90d
# 34  4b7c4fcdf964a520958b2fe3
# 35  5772ab6b498e80d8dcee6790
# 36  5a74820e1ffe971ebc0c31e8
# 37  5384f6a2498ec1985aa33311
# 38  4e2a764cd22d3f83c8847e76
# 39  4e50d390d22daf51d2899a54
# 40  520b5b5411d214f5f28b7d85
# 41  4dd4136b18384691b9b86fd0
# 42  4dc135180f2c14a8450cde21
# 43  4bae6b43f964a520e2af3be3
# 44  4b900cbbf964a520737233e3
# 45  4bf82aeb5efe2d7f78466a34
# 46  4cb0b60acbab236acbe2a273
# 47  50850171e4b0290494560b4f
# 48  5072abefe4b0e1b65f24d189
# 49  4fbd27a1e4b00902117e2cca

# %% [markdown]
# #### Visualize the restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                          Boardwalk Restaurant
# 1     Bellini's Italian Restaurant & Lounge Bar
# 2                               IKEA Restaurant
# 3                     Orchid Chinese Restaurant
# 4                                The Restaurant
# 5                       Restaurant Transilvania
# 6                            Ovation Restaurant
# 7                    Leelawadee Thai Restaurant
# 8                            Poppins Restaurant
# 9                                Taj Restaurant
# 10                     The Boathouse Restaurant
# 11                       Christina's Restaurant
# 12                    Tang's Chinese Restaurant
# 13                        88 chinese restaurant
# 14                    Beity Lebanese Restaurant
# 15                             Hotel Restaurant
# 16                             Shire Restaurant
# 17        Simons at Oxfords Wine Bar Restaurant
# 18                  Casanova Italian Restaurant
# 19                     Sam's Bar And Restaurant
# 20                             Elias Restaurant
# 21                      The Chambeli Restaurant
# 22                          George's Restaurant
# 23                       Christina's Restaurant
# 24                    The Restaurant at HASKINS
# 25                      Zen Japanese Restaurant
# 26                       Balkh Afgan Restaurant
# 27                  Shwan Restaurant & Takeaway
# 28                                        kisna
# 29                              Lupa Restaurant
# 30                                   Jury's Inn
# 31                       Posh Indian Restaurant
# 32                            Aspire Restaurant
# 33                               The Restaurant
# 34                              Ceno Restaurant
# 35                             Thyme Restaurant
# 36                            Dahlia Restaurant
# 37             Pilgrim House Chinese Restaurant
# 38                  Ventura Bay Tree Restaurant
# 39             Piggy's Coffee Shop & Restaurant
# 40                        Sainsburys Restaurant
# 41                              Taps Restaurant
# 42                                    Number 10
# 43                      Special Thai Restaurant
# 44                                      Oxfords
# 45     Jehangir Indian & Bangladeshi Restaurant
# 46                               The King and I
# 47                         The Grove Restaurant
# 48                            Zara's Restaurant
# 49                          Merchants Blue Moon
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map

# add a red circle marker
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Southampton Central',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dataframe_filtered.categories
# Out:
# 0                    Restaurant
# 1            Italian Restaurant
# 2       Scandinavian Restaurant
# 3            Chinese Restaurant
# 4                    Restaurant
# 5                    Restaurant
# 6                          None
# 7               Thai Restaurant
# 8                         Diner
# 9             Indian Restaurant
# 10           English Restaurant
# 11                   Restaurant
# 12           Chinese Restaurant
# 13         Cantonese Restaurant
# 14          Lebanese Restaurant
# 15               Breakfast Spot
# 16            Polish Restaurant
# 17                         Food
# 18           Italian Restaurant
# 19               Breakfast Spot
# 20             Greek Restaurant
# 21                   Restaurant
# 22             Greek Restaurant
# 23                         Café
# 24                         Café
# 25          Japanese Restaurant
# 26            Afghan Restaurant
# 27    Middle Eastern Restaurant
# 28            Indian Restaurant
# 29           Italian Restaurant
# 30                        Hotel
# 31            Indian Restaurant
# 32                   Restaurant
# 33                   Restaurant
# 34                          Bar
# 35                   Restaurant
# 36                   Restaurant
# 37                         None
# 38                   Restaurant
# 39                  Coffee Shop
# 40                         Café
# 41                   Restaurant
# 42     Mediterranean Restaurant
# 43              Thai Restaurant
# 44                    Gastropub
# 45            Indian Restaurant
# 46              Thai Restaurant
# 47                   Restaurant
# 48                         Café
# 49                   Steakhouse
# Name: categories, dtype: object

# %%
dataframe_filtered.categories.value_counts()
# Out:
# Restaurant                   12
# Indian Restaurant             4
# Café                          4
# Thai Restaurant               3
# Italian Restaurant            3
# Greek Restaurant              2
# Chinese Restaurant            2
# Breakfast Spot                2
# Bar                           1
# Hotel                         1
# English Restaurant            1
# Coffee Shop                   1
# Diner                         1
# Food                          1
# Japanese Restaurant           1
# Lebanese Restaurant           1
# Polish Restaurant             1
# Gastropub                     1
# Steakhouse                    1
# Middle Eastern Restaurant     1
# Cantonese Restaurant          1
# Scandinavian Restaurant       1
# Mediterranean Restaurant      1
# Afghan Restaurant             1
# Name: categories, dtype: int64

# %%
soton_grouped = dataframe_filtered.groupby('categories').mean().reset_index()
soton_grouped
# Out:
#                    categories        lat       lng     distance
# 0           Afghan Restaurant  50.906039 -1.396637  1234.000000
# 1                         Bar  50.927616 -1.391618  2716.000000
# 2              Breakfast Spot  50.906563 -1.400800  1069.000000
# 3                        Café  50.924035 -1.406055  3008.500000
# 4        Cantonese Restaurant  50.911926 -1.403879   852.000000
# 5          Chinese Restaurant  50.907835 -1.410205   418.500000
# 6                 Coffee Shop  50.897240 -1.379802  2670.000000
# 7                       Diner  50.902354 -1.404234   910.000000
# 8          English Restaurant  50.873014 -1.400751  3974.000000
# 9                        Food  50.897970 -1.397420  1592.000000
# 10                  Gastropub  50.898041 -1.397369  1589.000000
# 11           Greek Restaurant  50.900324 -1.403019  1141.000000
# 12                      Hotel  50.910702 -1.401491   940.000000
# 13          Indian Restaurant  50.912547 -1.409791  1303.250000
# 14         Italian Restaurant  50.899683 -1.401814  1251.000000
# 15        Japanese Restaurant  50.899392 -1.403511  1184.000000
# 16        Lebanese Restaurant  50.902418 -1.404238   905.000000
# 17   Mediterranean Restaurant  50.911667 -1.405727   729.000000
# 18  Middle Eastern Restaurant  50.911502 -1.393604  1494.000000
# 19          Polish Restaurant  50.912890 -1.399887  1147.000000
# 20                 Restaurant  50.916019 -1.405412  2212.916667
# 21    Scandinavian Restaurant  50.903382 -1.411634   511.000000
# 22                 Steakhouse  50.897308 -1.391874  1939.000000
# 23            Thai Restaurant  50.930457 -1.398392  3369.000000

# %%
soton_grouped_sorted = soton_grouped.sort_values('distance',ascending=True)
soton_grouped_sorted
# Out:
#                    categories        lat       lng     distance
# 5          Chinese Restaurant  50.907835 -1.410205   418.500000
# 21    Scandinavian Restaurant  50.903382 -1.411634   511.000000
# 17   Mediterranean Restaurant  50.911667 -1.405727   729.000000
# 4        Cantonese Restaurant  50.911926 -1.403879   852.000000
# 16        Lebanese Restaurant  50.902418 -1.404238   905.000000
# 7                       Diner  50.902354 -1.404234   910.000000
# 12                      Hotel  50.910702 -1.401491   940.000000
# 2              Breakfast Spot  50.906563 -1.400800  1069.000000
# 11           Greek Restaurant  50.900324 -1.403019  1141.000000
# 19          Polish Restaurant  50.912890 -1.399887  1147.000000
# 15        Japanese Restaurant  50.899392 -1.403511  1184.000000
# 0           Afghan Restaurant  50.906039 -1.396637  1234.000000
# 14         Italian Restaurant  50.899683 -1.401814  1251.000000
# 13          Indian Restaurant  50.912547 -1.409791  1303.250000
# 18  Middle Eastern Restaurant  50.911502 -1.393604  1494.000000
# 10                  Gastropub  50.898041 -1.397369  1589.000000
# 9                        Food  50.897970 -1.397420  1592.000000
# 22                 Steakhouse  50.897308 -1.391874  1939.000000
# 20                 Restaurant  50.916019 -1.405412  2212.916667
# 6                 Coffee Shop  50.897240 -1.379802  2670.000000
# 1                         Bar  50.927616 -1.391618  2716.000000
# 3                        Café  50.924035 -1.406055  3008.500000
# 23            Thai Restaurant  50.930457 -1.398392  3369.000000
# 8          English Restaurant  50.873014 -1.400751  3974.000000

# %%
print('There are {} uniques categories.'.format(len(soton_grouped_sorted['categories'].unique())))
# Out:
# There are 24 uniques categories.

# %% [markdown]
# ### Adding marker cluster to map

# %%
from folium.plugins import MarkerCluster

# %%
venues_map3 = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map

# add a red circle marker
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Southampton Central',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map3)


marker_cluster = MarkerCluster().add_to(venues_map3)

for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.Marker(
    location=[lat, lng],
    popup=label,
    icon=None,
    ).add_to(marker_cluster)


venues_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Creating clusters using k-means - Southampton

# %%
import random # library for random number generation
import numpy as np # library for vectorized computation
import pandas as pd # library to process data as dataframes

import matplotlib.pyplot as plt # plotting library
# backend for rendering plots within the browser
# %matplotlib inline 

from sklearn.cluster import KMeans 
from sklearn.datasets.samples_generator import make_blobs

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# set number of clusters
kclusters = 5

soton_grouped_clustering = soton_grouped.drop('categories', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(soton_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([2, 4, 2, 4, 0, 0, 4, 0, 1, 2], dtype=int32)

# %%
# add clustering labels
#soton_grouped_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

soton_grouped_sorted.head() # check the last columns!
# Out:
#     Cluster Labels                categories        lat       lng  distance
# 5                2        Chinese Restaurant  50.907835 -1.410205     418.5
# 21               4   Scandinavian Restaurant  50.903382 -1.411634     511.0
# 17               2  Mediterranean Restaurant  50.911667 -1.405727     729.0
# 4                4      Cantonese Restaurant  50.911926 -1.403879     852.0
# 16               0       Lebanese Restaurant  50.902418 -1.404238     905.0

# %%
soton_grouped_sorted.loc[soton_grouped_sorted['Cluster Labels'] == 0, soton_grouped_sorted.columns[[1] + list(range(5, soton_grouped_sorted.shape[1]))]]
# Out:
#              categories
# 16  Lebanese Restaurant
# 7                 Diner
# 2        Breakfast Spot
# 14   Italian Restaurant
# 9                  Food
# 22           Steakhouse
# 3                  Café

# %%
soton_grouped_sorted.loc[soton_grouped_sorted['Cluster Labels'] == 1, soton_grouped_sorted.columns[[1] + list(range(5, soton_grouped_sorted.shape[1]))]]
# Out:
#             categories
# 11    Greek Restaurant
# 8   English Restaurant

# %%
soton_grouped_sorted.loc[soton_grouped_sorted['Cluster Labels'] == 2, soton_grouped_sorted.columns[[1] + list(range(5, soton_grouped_sorted.shape[1]))]]
# Out:
#                    categories
# 5          Chinese Restaurant
# 17   Mediterranean Restaurant
# 19          Polish Restaurant
# 15        Japanese Restaurant
# 0           Afghan Restaurant
# 13          Indian Restaurant
# 18  Middle Eastern Restaurant
# 10                  Gastropub
# 20                 Restaurant
# 6                 Coffee Shop

# %%
soton_grouped_sorted.loc[soton_grouped_sorted['Cluster Labels'] == 3, soton_grouped_sorted.columns[[1] + list(range(5, soton_grouped_sorted.shape[1]))]]
# Out:
#          categories
# 1               Bar
# 23  Thai Restaurant

# %%
soton_grouped_sorted.loc[soton_grouped_sorted['Cluster Labels'] == 4, soton_grouped_sorted.columns[[1] + list(range(5, soton_grouped_sorted.shape[1]))]]
# Out:
#                  categories
# 21  Scandinavian Restaurant
# 4      Cantonese Restaurant
# 12                    Hotel

# %%
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lng, poi, cluster in zip(soton_grouped_sorted['lat'], soton_grouped_sorted['lng'],soton_grouped_sorted['categories'], soton_grouped_sorted['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(venues_map3)
       
venues_map3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Now, let's explore Portsmouth

# %%
address2 = 'Portsmouth Harbour, Portsmouth, UK'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address2)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 50.81813425 -1.12082115124301

# %%
search_query = 'restaurant'
radius = 8000
print(search_query + ' .... OK!')
# Out:
# restaurant .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=2I3LPFIYIHKOKRDUERZD4BGMBG1MBLDRH51BJVRROQ1LA220&client_secret=FD1DZORVTNISU5UKUBDQBFQIYLKXIVZQJ23IILFJFTNA4A2U&ll=50.81813425,-1.12082115124301&v=20180604&query=restaurant&radius=8000&limit=100'

# %%
results2 = requests.get(url).json()
results2
# Out:
# {'meta': {'code': 200, 'requestId': '5d9a0acb396de0002c348eca'},
#  'response': {'venues': [{'id': '4c225f589085d13acb3a86cc',
#     'name': 'Restaurant 27',
#     'location': {'address': '27A South Parade',
#      'crossStreet': 'Burgoyne Road',
#      'lat': 50.78090256249381,
#      'lng': -1.080821913552769,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78090256249381,
#        'lng': -1.080821913552769}],
#      'distance': 5009,
#      'postalCode': 'PO5 2JF',
#      'cc': 'GB',
#      'city': 'Southsea',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['27A South Parade (Burgoyne Road)',
#       'Southsea',
#       'Hampshire',
#       'PO5 2JF',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10c941735',
#       'name': 'French Restaurant',
#       'pluralName': 'French Restaurants',
#       'shortName': 'French',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '503a3e2be4b0451d7d6b7522',
#     'name': 'İstanbul Turkish & Kurdish Restaurant',
#     'location': {'lat': 50.785119049882326,
#      'lng': -1.091370731163266,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.785119049882326,
#        'lng': -1.091370731163266}],
#      'distance': 4219,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '53e91514498e60742355bbf6',
#     'name': 'restaurant holliday inn',
#     'location': {'lat': 50.78972349930224,
#      'lng': -1.0854107564172486,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78972349930224,
#        'lng': -1.0854107564172486}],
#      'distance': 4025,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a05',
#       'name': 'English Restaurant',
#       'pluralName': 'English Restaurants',
#       'shortName': 'English',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '50129224e4b09075800fd10d',
#     'name': 'The Restaurant',
#     'location': {'address': 'Knight & Lee',
#      'lat': 50.785065,
#      'lng': -1.088306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.785065,
#        'lng': -1.088306}],
#      'distance': 4334,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Knight & Lee', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4c893f84da5da1cd0bea3ae9',
#     'name': "G's Winebar & Restaurant",
#     'location': {'address': 'Royal Clarance Marina',
#      'lat': 50.80214771170987,
#      'lng': -1.1240630785413415,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.80214771170987,
#        'lng': -1.1240630785413415}],
#      'distance': 1794,
#      'postalCode': 'Po12 1fx',
#      'cc': 'GB',
#      'city': 'Gosport',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Royal Clarance Marina',
#       'Gosport',
#       'Hampshire',
#       'Po12 1fx',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d14b941735',
#       'name': 'Winery',
#       'pluralName': 'Wineries',
#       'shortName': 'Winery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '40468287'},
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4ec4375b61af4438d0bca5f9',
#     'name': 'Gandhi Indian Restaurant',
#     'location': {'lat': 50.810489451338846,
#      'lng': -1.078856159736486,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.810489451338846,
#        'lng': -1.078856159736486}],
#      'distance': 3071,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'shortName': 'Asian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '5bfabbdb8a6f17002c1169f9',
#     'name': 'Cedar Lebanese Restaurant',
#     'location': {'address': '49 Albert Road',
#      'lat': 50.787354,
#      'lng': -1.0808756,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.787354,
#        'lng': -1.0808756}],
#      'distance': 4431,
#      'postalCode': 'PO5 2SF',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['49 Albert Road',
#       'Portsmouth',
#       'Hampshire',
#       'PO5 2SF',
#       'United Kingdom']},
#     'categories': [{'id': '58daa1558bbb0b01f18ec1cd',
#       'name': 'Lebanese Restaurant',
#       'pluralName': 'Lebanese Restaurants',
#       'shortName': 'Lebanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4ba66817f964a520164f39e3',
#     'name': 'Loch Fyne',
#     'location': {'address': 'Gunwharf Quays',
#      'crossStreet': 'Unit 2 Vulcan Buildings',
#      'lat': 50.79441866955099,
#      'lng': -1.1066341839213616,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.79441866955099,
#        'lng': -1.1066341839213616}],
#      'distance': 2822,
#      'postalCode': 'PO1 3BF',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Gunwharf Quays (Unit 2 Vulcan Buildings)',
#       'Portsmouth',
#       'Hampshire',
#       'PO1 3BF',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1ce941735',
#       'name': 'Seafood Restaurant',
#       'pluralName': 'Seafood Restaurants',
#       'shortName': 'Seafood',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4e9d6eac5c5c1734ef85664a',
#     'name': 'Po-Young Chinese Restaurant',
#     'location': {'address': '5A Commercial Place',
#      'lat': 50.802022,
#      'lng': -1.087335,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.802022,
#        'lng': -1.087335}],
#      'distance': 2960,
#      'postalCode': 'PO1 4DT',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['5A Commercial Place',
#       'Portsmouth',
#       'Hampshire',
#       'PO1 4DT',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '57a8584c498e213efeee342b',
#     'name': "Victoriana's Restaurant",
#     'location': {'address': "Bemister's Lane",
#      'lat': 50.794795,
#      'lng': -1.120833,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.794795,
#        'lng': -1.120833}],
#      'distance': 2598,
#      'cc': 'GB',
#      'city': 'Gosport',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ["Bemister's Lane",
#       'Gosport',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '59a33abf535d6f722961a86d',
#     'name': 'Deep Blue Restaurant, Southsea Pier',
#     'location': {'address': 'Southsea Pier,',
#      'crossStreet': 'Eastney Esplanade',
#      'lat': 50.778313,
#      'lng': -1.0759115,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.778313,
#        'lng': -1.0759115}],
#      'distance': 5443,
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Southsea Pier, (Eastney Esplanade)',
#       'Portsmouth',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '52e81612bcbc57f1066b7a05',
#       'name': 'English Restaurant',
#       'pluralName': 'English Restaurants',
#       'shortName': 'English',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4c8941d697828cfa1dd5a2aa',
#     'name': "G's Winebar & Restaurant",
#     'location': {'address': 'Weevil Lane',
#      'lat': 50.80403489467716,
#      'lng': -1.0904264719558217,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.80403489467716,
#        'lng': -1.0904264719558217}],
#      'distance': 2652,
#      'postalCode': 'Po12 1fx',
#      'cc': 'GB',
#      'city': 'Gosport',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Weevil Lane',
#       'Gosport',
#       'Hampshire',
#       'Po12 1fx',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'shortName': 'Wine Bar',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4f8c3706e4b0e6f34b1710fd',
#     'name': "sandip's restaurant",
#     'location': {'lat': 50.81595500843999,
#      'lng': -1.0825911187755624,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.81595500843999,
#        'lng': -1.0825911187755624}],
#      'distance': 2699,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '52e3ca0b498e59e408b1a0dc',
#     'name': 'Debenhams Restaurant/Café',
#     'location': {'address': 'Commercial Road',
#      'lat': 50.80770640512597,
#      'lng': -1.0838440453254632,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.80770640512597,
#        'lng': -1.0838440453254632}],
#      'distance': 2848,
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Commercial Road',
#       'Portsmouth',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '5817430938fa51e55205a5c6',
#     'name': 'Jmart Japanese and Korean Restaurant',
#     'location': {'address': '206',
#      'crossStreet': 'Kingston Road',
#      'lat': 50.811952,
#      'lng': -1.079777,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.811952,
#        'lng': -1.079777}],
#      'distance': 2967,
#      'postalCode': 'PO2 7LR',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['206 (Kingston Road)',
#       'Portsmouth',
#       'Hampshire',
#       'PO2 7LR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4be2aabad27a20a1fd00905b',
#     'name': 'Debenhams',
#     'location': {'address': '134-142 Commercial Rd',
#      'lat': 50.80004029496772,
#      'lng': -1.0900820381561314,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.80004029496772,
#        'lng': -1.0900820381561314}],
#      'distance': 2955,
#      'postalCode': 'PO1 1ET',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['134-142 Commercial Rd',
#       'Portsmouth',
#       'Hampshire',
#       'PO1 1ET',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1f6941735',
#       'name': 'Department Store',
#       'pluralName': 'Department Stores',
#       'shortName': 'Department Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '5041bf8ce4b0a10506b579ae',
#     'name': 'Sealevel Restaurant & Bar',
#     'location': {'lat': 50.845879,
#      'lng': -1.090393,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.845879,
#        'lng': -1.090393}],
#      'distance': 3757,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4e2b1c2318a80bb058558948',
#     'name': 'The George Hotel',
#     'location': {'address': '84 Queen Street',
#      'lat': 50.79970054545797,
#      'lng': -1.1049123334215634,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.79970054545797,
#        'lng': -1.1049123334215634}],
#      'distance': 2337,
#      'postalCode': 'PO1 3HU',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['84 Queen Street',
#       'Portsmouth',
#       'Hampshire',
#       'PO1 3HU',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '5c4076dc3183940025890474',
#     'name': '113 Restaurant And Bar',
#     'location': {'lat': 50.795143,
#      'lng': -1.0950899,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.795143,
#        'lng': -1.0950899}],
#      'distance': 3134,
#      'postalCode': 'PO1 2AH',
#      'cc': 'GB',
#      'neighborhood': 'Guildhall',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Portsmouth',
#       'Hampshire',
#       'PO1 2AH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '58456efdebf0284fe76380bd',
#     'name': 'J Mart Japanese & Korean Restaurant 一嵐日韓料理',
#     'location': {'address': '206 Kingston Road',
#      'lat': 50.812054,
#      'lng': -1.0798,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.812054,
#        'lng': -1.0798}],
#      'distance': 2963,
#      'postalCode': 'PO2 7LR',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['206 Kingston Road',
#       'Portsmouth',
#       'Hampshire',
#       'PO2 7LR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4cc96789b3f5224b9a61f420',
#     'name': 'Golden Emperor Chinese Restaurant',
#     'location': {'lat': 50.79782,
#      'lng': -1.091982,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.79782,
#        'lng': -1.091982}],
#      'distance': 3037,
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Portsmouth', 'Hampshire', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '51fb9b79498e49e9f8a62140',
#     'name': 'Chimes Restaurant At Highbury College',
#     'location': {'lat': 50.79552996037177,
#      'lng': -1.0921008576559983,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.79552996037177,
#        'lng': -1.0921008576559983}],
#      'distance': 3227,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '5124c3d0e4b06a37a4173e98',
#     'name': 'Penang Laksa Restaurant',
#     'location': {'address': '3, Unicorn Road',
#      'lat': 50.80424845747774,
#      'lng': -1.078894929687026,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.80424845747774,
#        'lng': -1.078894929687026}],
#      'distance': 3329,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['3, Unicorn Road', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d156941735',
#       'name': 'Malay Restaurant',
#       'pluralName': 'Malay Restaurants',
#       'shortName': 'Malay',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/malaysian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4c9ba8919c6637043a5963fd',
#     'name': 'Prezzo',
#     'location': {'address': '43 The Boardwalk',
#      'lat': 50.84106421924381,
#      'lng': -1.0980766704980862,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.84106421924381,
#        'lng': -1.0980766704980862}],
#      'distance': 3012,
#      'postalCode': 'PO6 4TP',
#      'cc': 'GB',
#      'city': 'Port Solent',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['43 The Boardwalk',
#       'Port Solent',
#       'Hampshire',
#       'PO6 4TP',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4b6c62fef964a520d4352ce3',
#     'name': 'Sakura',
#     'location': {'address': '9 Albert Rd',
#      'lat': 50.78821062855919,
#      'lng': -1.0822074071407584,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78821062855919,
#        'lng': -1.0822074071407584}],
#      'distance': 4298,
#      'postalCode': 'PO5 2SE',
#      'cc': 'GB',
#      'neighborhood': 'Southsea',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['9 Albert Rd',
#       'Portsmouth',
#       'Hampshire',
#       'PO5 2SE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4cd6a2addfb4a1cdd212605c',
#     'name': 'Sarah turkish Restaurant',
#     'location': {'address': 'Fawcett road',
#      'lat': 50.79373,
#      'lng': -1.076356,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.79373,
#        'lng': -1.076356}],
#      'distance': 4143,
#      'cc': 'GB',
#      'city': 'Southsea',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Fawcett road',
#       'Southsea',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4cec17b3baa6a1cd5de7416c',
#     'name': 'Agora Restaurant',
#     'location': {'address': '9 Clarendon Rd.',
#      'lat': 50.78469275804901,
#      'lng': -1.0880264772888963,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78469275804901,
#        'lng': -1.0880264772888963}],
#      'distance': 4379,
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['9 Clarendon Rd.',
#       'Portsmouth',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10e941735',
#       'name': 'Greek Restaurant',
#       'pluralName': 'Greek Restaurants',
#       'shortName': 'Greek',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4e3320fd62845cff5a3ba9f4',
#     'name': 'Great Wall',
#     'location': {'address': '78A High St.',
#      'lat': 50.79489097656714,
#      'lng': -1.1164597985275935,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.79489097656714,
#        'lng': -1.1164597985275935}],
#      'distance': 2605,
#      'postalCode': 'PO12 1DS',
#      'cc': 'GB',
#      'city': 'Gosport',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['78A High St.',
#       'Gosport',
#       'Hampshire',
#       'PO12 1DS',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '57ab0ecf498ed701ee3c5dc0',
#     'name': 'Kung Fu Restaurant',
#     'location': {'address': '54 West Street',
#      'lat': 50.852276,
#      'lng': -1.1775578,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.852276,
#        'lng': -1.1775578}],
#      'distance': 5509,
#      'postalCode': 'PO16 0JN',
#      'cc': 'GB',
#      'city': 'Fareham',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['54 West Street',
#       'Fareham',
#       'Hampshire',
#       'PO16 0JN',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '5259b0b111d26f015ea65608',
#     'name': 'sarah restaurant',
#     'location': {'lat': 50.793835,
#      'lng': -1.076306,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.793835,
#        'lng': -1.076306}],
#      'distance': 4138,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4cc20f7f1e596dcb7e25c067',
#     'name': 'Touareg restaurant',
#     'location': {'lat': 50.78917,
#      'lng': -1.083345,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78917,
#        'lng': -1.083345}],
#      'distance': 4164,
#      'cc': 'GB',
#      'city': 'Nettlestone',
#      'state': 'Isle of Wight',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Nettlestone', 'Isle of Wight', 'United Kingdom']},
#     'categories': [],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '51a51676498e1de1683803f9',
#     'name': '@Asia Japanese Restaurant',
#     'location': {'lat': 50.784823674651776,
#      'lng': -1.0915358127211736,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.784823674651776,
#        'lng': -1.0915358127211736}],
#      'distance': 4242,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'shortName': 'Japanese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4f608b3710818c5588b4c4c8',
#     'name': 'Nirvana Restaurant Southsea',
#     'location': {'address': '17 Albert Road Southsea',
#      'lat': 50.78814719838939,
#      'lng': -1.0819172859191895,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78814719838939,
#        'lng': -1.0819172859191895}],
#      'distance': 4316,
#      'postalCode': 'PO5 2SE',
#      'cc': 'GB',
#      'city': 'Southsea',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['17 Albert Road Southsea',
#       'Southsea',
#       'Hampshire',
#       'PO5 2SE',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4e7df9b0775b53d25b7dcd93',
#     'name': 'Dubai Restaurant',
#     'location': {'address': '134 Albert Road',
#      'lat': 50.78665659682888,
#      'lng': -1.0751671440877153,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78665659682888,
#        'lng': -1.0751671440877153}],
#      'distance': 4753,
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['134 Albert Road',
#       'Portsmouth',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d115941735',
#       'name': 'Middle Eastern Restaurant',
#       'pluralName': 'Middle Eastern Restaurants',
#       'shortName': 'Middle Eastern',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '521d01ba11d21a1bbd0810f0',
#     'name': "Bobby's",
#     'location': {'address': '18 Stoke Road',
#      'lat': 50.79457644302583,
#      'lng': -1.13038357738322,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.79457644302583,
#        'lng': -1.13038357738322}],
#      'distance': 2707,
#      'postalCode': 'PO12 1JB',
#      'cc': 'GB',
#      'city': 'Gosport',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['18 Stoke Road',
#       'Gosport',
#       'Hampshire',
#       'PO12 1JB',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '52b1f8a1498ec39be5ab3b72',
#     'name': 'Buffalo Cafe Restaurant',
#     'location': {'lat': 50.78794723297043,
#      'lng': -1.0820077677066793,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78794723297043,
#        'lng': -1.0820077677066793}],
#      'distance': 4329,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c0941735',
#       'name': 'Mediterranean Restaurant',
#       'pluralName': 'Mediterranean Restaurants',
#       'shortName': 'Mediterranean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4dc7a274e4cd169dc6810582',
#     'name': 'Highbury Cafe & Restaurant',
#     'location': {'lat': 50.840269,
#      'lng': -1.068249,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.840269,
#        'lng': -1.068249}],
#      'distance': 4442,
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Portsmouth', 'Hampshire', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '54fb3fe3498eb4382582da5b',
#     'name': 'Pebbles Fish And Wine Restaurant',
#     'location': {'lat': 50.78662210541675,
#      'lng': -1.1614795347061415,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78662210541675,
#        'lng': -1.1614795347061415}],
#      'distance': 4526,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4f3aaf46e4b0e724f17f15f1',
#     'name': 'Pitch Side Restaurant, Fratton Park',
#     'location': {'address': 'Fratton Park',
#      'lat': 50.797236,
#      'lng': -1.064455,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.797236,
#        'lng': -1.064455}],
#      'distance': 4597,
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Fratton Park',
#       'Portsmouth',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d188941735',
#       'name': 'Soccer Stadium',
#       'pluralName': 'Soccer Stadiums',
#       'shortName': 'Soccer',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/stadium_soccer_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4b6c7694f964a520293c2ce3',
#     'name': 'Goa Indian Restaurant',
#     'location': {'lat': 50.78764735221323,
#      'lng': -1.0816233050299728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78764735221323,
#        'lng': -1.0816233050299728}],
#      'distance': 4372,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4ed1601f2c5bc3505829a791',
#     'name': 'Bodrum',
#     'location': {'address': '165-167 Albert Rd',
#      'lat': 50.786733443188645,
#      'lng': -1.0748723011423849,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.786733443188645,
#        'lng': -1.0748723011423849}],
#      'distance': 4761,
#      'postalCode': 'PO4 0JW',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['165-167 Albert Rd',
#       'Portsmouth',
#       'Hampshire',
#       'PO4 0JW',
#       'United Kingdom']},
#     'categories': [{'id': '4f04af1f2fb6e1c99f3db0bb',
#       'name': 'Turkish Restaurant',
#       'pluralName': 'Turkish Restaurants',
#       'shortName': 'Turkish',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/turkish_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4e8f24edb80369c969bf1872',
#     'name': 'Twins Chinese Hot Pot Restaurant',
#     'location': {'address': '255 Albert Road',
#      'crossStreet': 'Southsea',
#      'lat': 50.786522,
#      'lng': -1.070801,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.786522,
#        'lng': -1.070801}],
#      'distance': 4976,
#      'postalCode': 'PO4 OJR',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['255 Albert Road (Southsea)',
#       'Portsmouth',
#       'Hampshire',
#       'PO4 OJR',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'shortName': 'Chinese',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4e01d3f062843b639cfc96af',
#     'name': "Nino's Cafe & Restaurant",
#     'location': {'address': '38 High Street',
#      'lat': 50.847340625724485,
#      'lng': -1.0618497222923355,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.847340625724485,
#        'lng': -1.0618497222923355}],
#      'distance': 5268,
#      'postalCode': 'PO6 3BZ',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['38 High Street',
#       'Portsmouth',
#       'Hampshire',
#       'PO6 3BZ',
#       'United Kingdom']},
#     'categories': [],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4be5a6392457a593d7c3ab15',
#     'name': 'Bombay Bay Indian Restaurant',
#     'location': {'address': 'Southsea marina',
#      'lat': 50.791666,
#      'lng': -1.033407,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.791666,
#        'lng': -1.033407}],
#      'distance': 6818,
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['Southsea marina',
#       'Portsmouth',
#       'Hampshire',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4c193e87fe5a76b0fb4a0315',
#     'name': 'T & J Mahal',
#     'location': {'address': '39 Elm Grove',
#      'lat': 50.79043076764807,
#      'lng': -1.0891236253702576,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.79043076764807,
#        'lng': -1.0891236253702576}],
#      'distance': 3805,
#      'postalCode': 'PO5 1JF',
#      'cc': 'GB',
#      'city': 'Portsmouth',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['39 Elm Grove',
#       'Portsmouth',
#       'Hampshire',
#       'PO5 1JF',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'shortName': 'Indian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '5b41fe2373fe25002c0cc20c',
#     'name': 'Chef’s Delight Cafe & Restaurant',
#     'location': {'lat': 50.800994,
#      'lng': -1.201262,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.800994,
#        'lng': -1.201262}],
#      'distance': 5971,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'shortName': 'Restaurant',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '57efae33498ed8b7dbc03127',
#     'name': "Tony's Café and Restaurant",
#     'location': {'address': '83 High Street',
#      'lat': 50.80121,
#      'lng': -1.201279,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.80121,
#        'lng': -1.201279}],
#      'distance': 5964,
#      'postalCode': 'PO13 9BU',
#      'cc': 'GB',
#      'city': 'Lee-on-the-Solent',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['83 High Street',
#       'Lee-on-the-Solent',
#       'Hampshire',
#       'PO13 9BU',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'shortName': 'Breakfast',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4e770f9062e12635171d3a83',
#     'name': 'The Solent Restaurant',
#     'location': {'lat': 50.80194688670608,
#      'lng': -1.2024388579569492,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.80194688670608,
#        'lng': -1.2024388579569492}],
#      'distance': 6017,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '4b65afd7f964a520aef92ae3',
#     'name': 'ASK Italian',
#     'location': {'address': '10 West Street, Fareham Hants',
#      'lat': 50.852214,
#      'lng': -1.174928,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.852214,
#        'lng': -1.174928}],
#      'distance': 5372,
#      'postalCode': 'PO16 0BH',
#      'cc': 'GB',
#      'city': 'Fareham',
#      'state': 'Hampshire',
#      'country': 'United Kingdom',
#      'formattedAddress': ['10 West Street, Fareham Hants',
#       'Fareham',
#       'Hampshire',
#       'PO16 0BH',
#       'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False},
#    {'id': '510ecdd3e4b0607cf4a3dd3c',
#     'name': 'Twins Korean BBQ',
#     'location': {'address': '221 Albert Road',
#      'lat': 50.78947146955999,
#      'lng': -1.072914628201136,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 50.78947146955999,
#        'lng': -1.072914628201136}],
#      'distance': 4641,
#      'cc': 'GB',
#      'country': 'United Kingdom',
#      'formattedAddress': ['221 Albert Road', 'United Kingdom']},
#     'categories': [{'id': '4bf58dd8d48988d113941735',
#       'name': 'Korean Restaurant',
#       'pluralName': 'Korean Restaurants',
#       'shortName': 'Korean',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1570376395',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues2 = results2['response']['venues']

# tranform venues into a dataframe
dataframe2 = json_normalize(venues2)
dataframe2.head()
# Out:
#                          id                                   name  \
# 0  4c225f589085d13acb3a86cc                          Restaurant 27
# 1  503a3e2be4b0451d7d6b7522  İstanbul Turkish & Kurdish Restaurant
# 2  53e91514498e60742355bbf6                restaurant holliday inn
# 3  50129224e4b09075800fd10d                         The Restaurant
# 4  4c893f84da5da1cd0bea3ae9               G's Winebar & Restaurant
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10c941735', 'name': 'F...  v-1570376395    False
# 1  [{'id': '4f04af1f2fb6e1c99f3db0bb', 'name': 'T...  v-1570376395    False
# 2  [{'id': '52e81612bcbc57f1066b7a05', 'name': 'E...  v-1570376395    False
# 3  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1570376395    False
# 4  [{'id': '4bf58dd8d48988d14b941735', 'name': 'W...  v-1570376395    False
#
#         location.address location.crossStreet  location.lat  location.lng  \
# 0       27A South Parade        Burgoyne Road     50.780903     -1.080822
# 1                    NaN                  NaN     50.785119     -1.091371
# 2                    NaN                  NaN     50.789723     -1.085411
# 3           Knight & Lee                  NaN     50.785065     -1.088306
# 4  Royal Clarance Marina                  NaN     50.802148     -1.124063
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 50.78090256249381...               5009
# 1  [{'label': 'display', 'lat': 50.78511904988232...               4219
# 2  [{'label': 'display', 'lat': 50.78972349930224...               4025
# 3  [{'label': 'display', 'lat': 50.785065, 'lng':...               4334
# 4  [{'label': 'display', 'lat': 50.80214771170987...               1794
#
#   location.postalCode location.cc location.city location.state  \
# 0             PO5 2JF          GB      Southsea      Hampshire
# 1                 NaN          GB           NaN            NaN
# 2                 NaN          GB           NaN            NaN
# 3                 NaN          GB           NaN            NaN
# 4            Po12 1fx          GB       Gosport      Hampshire
#
#   location.country                          location.formattedAddress  \
# 0   United Kingdom  [27A South Parade (Burgoyne Road), Southsea, H...
# 1   United Kingdom                                   [United Kingdom]
# 2   United Kingdom                                   [United Kingdom]
# 3   United Kingdom                     [Knight & Lee, United Kingdom]
# 4   United Kingdom  [Royal Clarance Marina, Gosport, Hampshire, Po...
#
#   venuePage.id location.neighborhood
# 0          NaN                   NaN
# 1          NaN                   NaN
# 2          NaN                   NaN
# 3          NaN                   NaN
# 4     40468287                   NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns2 = ['name', 'categories'] + [col for col in dataframe2.columns if col.startswith('location.')] + ['id']
dataframe_filtered2 = dataframe2.loc[:, filtered_columns2]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered2['categories'] = dataframe_filtered2.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered2.columns = [column.split('.')[-1] for column in dataframe_filtered2.columns]

dataframe_filtered2
# Out:
#                                           name                 categories  \
# 0                                Restaurant 27          French Restaurant
# 1        İstanbul Turkish & Kurdish Restaurant         Turkish Restaurant
# 2                      restaurant holliday inn         English Restaurant
# 3                               The Restaurant                       Café
# 4                     G's Winebar & Restaurant                     Winery
# 5                     Gandhi Indian Restaurant           Asian Restaurant
# 6                    Cedar Lebanese Restaurant        Lebanese Restaurant
# 7                                    Loch Fyne         Seafood Restaurant
# 8                  Po-Young Chinese Restaurant         Chinese Restaurant
# 9                      Victoriana's Restaurant             Breakfast Spot
# 10         Deep Blue Restaurant, Southsea Pier         English Restaurant
# 11                    G's Winebar & Restaurant                   Wine Bar
# 12                         sandip's restaurant                 Restaurant
# 13                   Debenhams Restaurant/Café                       Café
# 14        Jmart Japanese and Korean Restaurant        Japanese Restaurant
# 15                                   Debenhams           Department Store
# 16                   Sealevel Restaurant & Bar                 Restaurant
# 17                            The George Hotel                 Restaurant
# 18                      113 Restaurant And Bar                 Restaurant
# 19  J Mart Japanese & Korean Restaurant 一嵐日韓料理        Japanese Restaurant
# 20           Golden Emperor Chinese Restaurant         Chinese Restaurant
# 21       Chimes Restaurant At Highbury College                 Restaurant
# 22                     Penang Laksa Restaurant           Malay Restaurant
# 23                                      Prezzo         Italian Restaurant
# 24                                      Sakura        Japanese Restaurant
# 25                    Sarah turkish Restaurant                       None
# 26                            Agora Restaurant           Greek Restaurant
# 27                                  Great Wall         Chinese Restaurant
# 28                          Kung Fu Restaurant                 Restaurant
# 29                            sarah restaurant  Middle Eastern Restaurant
# 30                          Touareg restaurant                       None
# 31                   @Asia Japanese Restaurant        Japanese Restaurant
# 32                 Nirvana Restaurant Southsea          Indian Restaurant
# 33                            Dubai Restaurant  Middle Eastern Restaurant
# 34                                     Bobby's         Italian Restaurant
# 35                     Buffalo Cafe Restaurant   Mediterranean Restaurant
# 36                  Highbury Cafe & Restaurant                       Café
# 37            Pebbles Fish And Wine Restaurant                 Restaurant
# 38         Pitch Side Restaurant, Fratton Park             Soccer Stadium
# 39                       Goa Indian Restaurant          Indian Restaurant
# 40                                      Bodrum         Turkish Restaurant
# 41            Twins Chinese Hot Pot Restaurant         Chinese Restaurant
# 42                    Nino's Cafe & Restaurant                       None
# 43                Bombay Bay Indian Restaurant          Indian Restaurant
# 44                                 T & J Mahal          Indian Restaurant
# 45            Chef’s Delight Cafe & Restaurant                 Restaurant
# 46                  Tony's Café and Restaurant             Breakfast Spot
# 47                       The Solent Restaurant                       Café
# 48                                 ASK Italian         Italian Restaurant
# 49                            Twins Korean BBQ          Korean Restaurant
#
#                           address              crossStreet        lat  \
# 0                27A South Parade            Burgoyne Road  50.780903
# 1                             NaN                      NaN  50.785119
# 2                             NaN                      NaN  50.789723
# 3                    Knight & Lee                      NaN  50.785065
# 4           Royal Clarance Marina                      NaN  50.802148
# 5                             NaN                      NaN  50.810489
# 6                  49 Albert Road                      NaN  50.787354
# 7                  Gunwharf Quays  Unit 2 Vulcan Buildings  50.794419
# 8             5A Commercial Place                      NaN  50.802022
# 9                 Bemister's Lane                      NaN  50.794795
# 10                 Southsea Pier,        Eastney Esplanade  50.778313
# 11                    Weevil Lane                      NaN  50.804035
# 12                            NaN                      NaN  50.815955
# 13                Commercial Road                      NaN  50.807706
# 14                            206            Kingston Road  50.811952
# 15          134-142 Commercial Rd                      NaN  50.800040
# 16                            NaN                      NaN  50.845879
# 17                84 Queen Street                      NaN  50.799701
# 18                            NaN                      NaN  50.795143
# 19              206 Kingston Road                      NaN  50.812054
# 20                            NaN                      NaN  50.797820
# 21                            NaN                      NaN  50.795530
# 22                3, Unicorn Road                      NaN  50.804248
# 23               43 The Boardwalk                      NaN  50.841064
# 24                    9 Albert Rd                      NaN  50.788211
# 25                   Fawcett road                      NaN  50.793730
# 26                9 Clarendon Rd.                      NaN  50.784693
# 27                   78A High St.                      NaN  50.794891
# 28                 54 West Street                      NaN  50.852276
# 29                            NaN                      NaN  50.793835
# 30                            NaN                      NaN  50.789170
# 31                            NaN                      NaN  50.784824
# 32        17 Albert Road Southsea                      NaN  50.788147
# 33                134 Albert Road                      NaN  50.786657
# 34                  18 Stoke Road                      NaN  50.794576
# 35                            NaN                      NaN  50.787947
# 36                            NaN                      NaN  50.840269
# 37                            NaN                      NaN  50.786622
# 38                   Fratton Park                      NaN  50.797236
# 39                            NaN                      NaN  50.787647
# 40              165-167 Albert Rd                      NaN  50.786733
# 41                255 Albert Road                 Southsea  50.786522
# 42                 38 High Street                      NaN  50.847341
# 43                Southsea marina                      NaN  50.791666
# 44                   39 Elm Grove                      NaN  50.790431
# 45                            NaN                      NaN  50.800994
# 46                 83 High Street                      NaN  50.801210
# 47                            NaN                      NaN  50.801947
# 48  10 West Street, Fareham Hants                      NaN  50.852214
# 49                221 Albert Road                      NaN  50.789471
#
#          lng                                     labeledLatLngs  distance  \
# 0  -1.080822  [{'label': 'display', 'lat': 50.78090256249381...      5009
# 1  -1.091371  [{'label': 'display', 'lat': 50.78511904988232...      4219
# 2  -1.085411  [{'label': 'display', 'lat': 50.78972349930224...      4025
# 3  -1.088306  [{'label': 'display', 'lat': 50.785065, 'lng':...      4334
# 4  -1.124063  [{'label': 'display', 'lat': 50.80214771170987...      1794
# 5  -1.078856  [{'label': 'display', 'lat': 50.81048945133884...      3071
# 6  -1.080876  [{'label': 'display', 'lat': 50.787354, 'lng':...      4431
# 7  -1.106634  [{'label': 'display', 'lat': 50.79441866955099...      2822
# 8  -1.087335  [{'label': 'display', 'lat': 50.802022, 'lng':...      2960
# 9  -1.120833  [{'label': 'display', 'lat': 50.794795, 'lng':...      2598
# 10 -1.075911  [{'label': 'display', 'lat': 50.778313, 'lng':...      5443
# 11 -1.090426  [{'label': 'display', 'lat': 50.80403489467716...      2652
# 12 -1.082591  [{'label': 'display', 'lat': 50.81595500843999...      2699
# 13 -1.083844  [{'label': 'display', 'lat': 50.80770640512597...      2848
# 14 -1.079777  [{'label': 'display', 'lat': 50.811952, 'lng':...      2967
# 15 -1.090082  [{'label': 'display', 'lat': 50.80004029496772...      2955
# 16 -1.090393  [{'label': 'display', 'lat': 50.845879, 'lng':...      3757
# 17 -1.104912  [{'label': 'display', 'lat': 50.79970054545797...      2337
# 18 -1.095090  [{'label': 'display', 'lat': 50.795143, 'lng':...      3134
# 19 -1.079800  [{'label': 'display', 'lat': 50.812054, 'lng':...      2963
# 20 -1.091982  [{'label': 'display', 'lat': 50.79782, 'lng': ...      3037
# 21 -1.092101  [{'label': 'display', 'lat': 50.79552996037177...      3227
# 22 -1.078895  [{'label': 'display', 'lat': 50.80424845747774...      3329
# 23 -1.098077  [{'label': 'display', 'lat': 50.84106421924381...      3012
# 24 -1.082207  [{'label': 'display', 'lat': 50.78821062855919...      4298
# 25 -1.076356  [{'label': 'display', 'lat': 50.79373, 'lng': ...      4143
# 26 -1.088026  [{'label': 'display', 'lat': 50.78469275804901...      4379
# 27 -1.116460  [{'label': 'display', 'lat': 50.79489097656714...      2605
# 28 -1.177558  [{'label': 'display', 'lat': 50.852276, 'lng':...      5509
# 29 -1.076306  [{'label': 'display', 'lat': 50.793835, 'lng':...      4138
# 30 -1.083345  [{'label': 'display', 'lat': 50.78917, 'lng': ...      4164
# 31 -1.091536  [{'label': 'display', 'lat': 50.78482367465177...      4242
# 32 -1.081917  [{'label': 'display', 'lat': 50.78814719838939...      4316
# 33 -1.075167  [{'label': 'display', 'lat': 50.78665659682888...      4753
# 34 -1.130384  [{'label': 'display', 'lat': 50.79457644302583...      2707
# 35 -1.082008  [{'label': 'display', 'lat': 50.78794723297043...      4329
# 36 -1.068249  [{'label': 'display', 'lat': 50.840269, 'lng':...      4442
# 37 -1.161480  [{'label': 'display', 'lat': 50.78662210541675...      4526
# 38 -1.064455  [{'label': 'display', 'lat': 50.797236, 'lng':...      4597
# 39 -1.081623  [{'label': 'display', 'lat': 50.78764735221323...      4372
# 40 -1.074872  [{'label': 'display', 'lat': 50.78673344318864...      4761
# 41 -1.070801  [{'label': 'display', 'lat': 50.786522, 'lng':...      4976
# 42 -1.061850  [{'label': 'display', 'lat': 50.84734062572448...      5268
# 43 -1.033407  [{'label': 'display', 'lat': 50.791666, 'lng':...      6818
# 44 -1.089124  [{'label': 'display', 'lat': 50.79043076764807...      3805
# 45 -1.201262  [{'label': 'display', 'lat': 50.800994, 'lng':...      5971
# 46 -1.201279  [{'label': 'display', 'lat': 50.80121, 'lng': ...      5964
# 47 -1.202439  [{'label': 'display', 'lat': 50.80194688670608...      6017
# 48 -1.174928  [{'label': 'display', 'lat': 50.852214, 'lng':...      5372
# 49 -1.072915  [{'label': 'display', 'lat': 50.78947146955999...      4641
#
#    postalCode  cc               city          state         country  \
# 0     PO5 2JF  GB           Southsea      Hampshire  United Kingdom
# 1         NaN  GB                NaN            NaN  United Kingdom
# 2         NaN  GB                NaN            NaN  United Kingdom
# 3         NaN  GB                NaN            NaN  United Kingdom
# 4    Po12 1fx  GB            Gosport      Hampshire  United Kingdom
# 5         NaN  GB                NaN            NaN  United Kingdom
# 6     PO5 2SF  GB         Portsmouth      Hampshire  United Kingdom
# 7     PO1 3BF  GB         Portsmouth      Hampshire  United Kingdom
# 8     PO1 4DT  GB         Portsmouth      Hampshire  United Kingdom
# 9         NaN  GB            Gosport      Hampshire  United Kingdom
# 10        NaN  GB         Portsmouth      Hampshire  United Kingdom
# 11   Po12 1fx  GB            Gosport      Hampshire  United Kingdom
# 12        NaN  GB                NaN            NaN  United Kingdom
# 13        NaN  GB         Portsmouth      Hampshire  United Kingdom
# 14    PO2 7LR  GB         Portsmouth      Hampshire  United Kingdom
# 15    PO1 1ET  GB         Portsmouth      Hampshire  United Kingdom
# 16        NaN  GB                NaN            NaN  United Kingdom
# 17    PO1 3HU  GB         Portsmouth      Hampshire  United Kingdom
# 18    PO1 2AH  GB         Portsmouth      Hampshire  United Kingdom
# 19    PO2 7LR  GB         Portsmouth      Hampshire  United Kingdom
# 20        NaN  GB         Portsmouth      Hampshire  United Kingdom
# 21        NaN  GB                NaN            NaN  United Kingdom
# 22        NaN  GB                NaN            NaN  United Kingdom
# 23    PO6 4TP  GB        Port Solent      Hampshire  United Kingdom
# 24    PO5 2SE  GB         Portsmouth      Hampshire  United Kingdom
# 25        NaN  GB           Southsea      Hampshire  United Kingdom
# 26        NaN  GB         Portsmouth      Hampshire  United Kingdom
# 27   PO12 1DS  GB            Gosport      Hampshire  United Kingdom
# 28   PO16 0JN  GB            Fareham      Hampshire  United Kingdom
# 29        NaN  GB                NaN            NaN  United Kingdom
# 30        NaN  GB        Nettlestone  Isle of Wight  United Kingdom
# 31        NaN  GB                NaN            NaN  United Kingdom
# 32    PO5 2SE  GB           Southsea      Hampshire  United Kingdom
# 33        NaN  GB         Portsmouth      Hampshire  United Kingdom
# 34   PO12 1JB  GB            Gosport      Hampshire  United Kingdom
# 35        NaN  GB                NaN            NaN  United Kingdom
# 36        NaN  GB         Portsmouth      Hampshire  United Kingdom
# 37        NaN  GB                NaN            NaN  United Kingdom
# 38        NaN  GB         Portsmouth      Hampshire  United Kingdom
# 39        NaN  GB                NaN            NaN  United Kingdom
# 40    PO4 0JW  GB         Portsmouth      Hampshire  United Kingdom
# 41    PO4 OJR  GB         Portsmouth      Hampshire  United Kingdom
# 42    PO6 3BZ  GB         Portsmouth      Hampshire  United Kingdom
# 43        NaN  GB         Portsmouth      Hampshire  United Kingdom
# 44    PO5 1JF  GB         Portsmouth      Hampshire  United Kingdom
# 45        NaN  GB                NaN            NaN  United Kingdom
# 46   PO13 9BU  GB  Lee-on-the-Solent      Hampshire  United Kingdom
# 47        NaN  GB                NaN            NaN  United Kingdom
# 48   PO16 0BH  GB            Fareham      Hampshire  United Kingdom
# 49        NaN  GB                NaN            NaN  United Kingdom
#
#                                      formattedAddress neighborhood  \
# 0   [27A South Parade (Burgoyne Road), Southsea, H...          NaN
# 1                                    [United Kingdom]          NaN
# 2                                    [United Kingdom]          NaN
# 3                      [Knight & Lee, United Kingdom]          NaN
# 4   [Royal Clarance Marina, Gosport, Hampshire, Po...          NaN
# 5                                    [United Kingdom]          NaN
# 6   [49 Albert Road, Portsmouth, Hampshire, PO5 2S...          NaN
# 7   [Gunwharf Quays (Unit 2 Vulcan Buildings), Por...          NaN
# 8   [5A Commercial Place, Portsmouth, Hampshire, P...          NaN
# 9   [Bemister's Lane, Gosport, Hampshire, United K...          NaN
# 10  [Southsea Pier, (Eastney Esplanade), Portsmout...          NaN
# 11  [Weevil Lane, Gosport, Hampshire, Po12 1fx, Un...          NaN
# 12                                   [United Kingdom]          NaN
# 13  [Commercial Road, Portsmouth, Hampshire, Unite...          NaN
# 14  [206 (Kingston Road), Portsmouth, Hampshire, P...          NaN
# 15  [134-142 Commercial Rd, Portsmouth, Hampshire,...          NaN
# 16                                   [United Kingdom]          NaN
# 17  [84 Queen Street, Portsmouth, Hampshire, PO1 3...          NaN
# 18   [Portsmouth, Hampshire, PO1 2AH, United Kingdom]    Guildhall
# 19  [206 Kingston Road, Portsmouth, Hampshire, PO2...          NaN
# 20            [Portsmouth, Hampshire, United Kingdom]          NaN
# 21                                   [United Kingdom]          NaN
# 22                  [3, Unicorn Road, United Kingdom]          NaN
# 23  [43 The Boardwalk, Port Solent, Hampshire, PO6...          NaN
# 24  [9 Albert Rd, Portsmouth, Hampshire, PO5 2SE, ...     Southsea
# 25  [Fawcett road, Southsea, Hampshire, United Kin...          NaN
# 26  [9 Clarendon Rd., Portsmouth, Hampshire, Unite...          NaN
# 27  [78A High St., Gosport, Hampshire, PO12 1DS, U...          NaN
# 28  [54 West Street, Fareham, Hampshire, PO16 0JN,...          NaN
# 29                                   [United Kingdom]          NaN
# 30       [Nettlestone, Isle of Wight, United Kingdom]          NaN
# 31                                   [United Kingdom]          NaN
# 32  [17 Albert Road Southsea, Southsea, Hampshire,...          NaN
# 33  [134 Albert Road, Portsmouth, Hampshire, Unite...          NaN
# 34  [18 Stoke Road, Gosport, Hampshire, PO12 1JB, ...          NaN
# 35                                   [United Kingdom]          NaN
# 36            [Portsmouth, Hampshire, United Kingdom]          NaN
# 37                                   [United Kingdom]          NaN
# 38  [Fratton Park, Portsmouth, Hampshire, United K...          NaN
# 39                                   [United Kingdom]          NaN
# 40  [165-167 Albert Rd, Portsmouth, Hampshire, PO4...          NaN
# 41  [255 Albert Road (Southsea), Portsmouth, Hamps...          NaN
# 42  [38 High Street, Portsmouth, Hampshire, PO6 3B...          NaN
# 43  [Southsea marina, Portsmouth, Hampshire, Unite...          NaN
# 44  [39 Elm Grove, Portsmouth, Hampshire, PO5 1JF,...          NaN
# 45                                   [United Kingdom]          NaN
# 46  [83 High Street, Lee-on-the-Solent, Hampshire,...          NaN
# 47                                   [United Kingdom]          NaN
# 48  [10 West Street, Fareham Hants, Fareham, Hamps...          NaN
# 49                  [221 Albert Road, United Kingdom]          NaN
#
#                           id
# 0   4c225f589085d13acb3a86cc
# 1   503a3e2be4b0451d7d6b7522
# 2   53e91514498e60742355bbf6
# 3   50129224e4b09075800fd10d
# 4   4c893f84da5da1cd0bea3ae9
# 5   4ec4375b61af4438d0bca5f9
# 6   5bfabbdb8a6f17002c1169f9
# 7   4ba66817f964a520164f39e3
# 8   4e9d6eac5c5c1734ef85664a
# 9   57a8584c498e213efeee342b
# 10  59a33abf535d6f722961a86d
# 11  4c8941d697828cfa1dd5a2aa
# 12  4f8c3706e4b0e6f34b1710fd
# 13  52e3ca0b498e59e408b1a0dc
# 14  5817430938fa51e55205a5c6
# 15  4be2aabad27a20a1fd00905b
# 16  5041bf8ce4b0a10506b579ae
# 17  4e2b1c2318a80bb058558948
# 18  5c4076dc3183940025890474
# 19  58456efdebf0284fe76380bd
# 20  4cc96789b3f5224b9a61f420
# 21  51fb9b79498e49e9f8a62140
# 22  5124c3d0e4b06a37a4173e98
# 23  4c9ba8919c6637043a5963fd
# 24  4b6c62fef964a520d4352ce3
# 25  4cd6a2addfb4a1cdd212605c
# 26  4cec17b3baa6a1cd5de7416c
# 27  4e3320fd62845cff5a3ba9f4
# 28  57ab0ecf498ed701ee3c5dc0
# 29  5259b0b111d26f015ea65608
# 30  4cc20f7f1e596dcb7e25c067
# 31  51a51676498e1de1683803f9
# 32  4f608b3710818c5588b4c4c8
# 33  4e7df9b0775b53d25b7dcd93
# 34  521d01ba11d21a1bbd0810f0
# 35  52b1f8a1498ec39be5ab3b72
# 36  4dc7a274e4cd169dc6810582
# 37  54fb3fe3498eb4382582da5b
# 38  4f3aaf46e4b0e724f17f15f1
# 39  4b6c7694f964a520293c2ce3
# 40  4ed1601f2c5bc3505829a791
# 41  4e8f24edb80369c969bf1872
# 42  4e01d3f062843b639cfc96af
# 43  4be5a6392457a593d7c3ab15
# 44  4c193e87fe5a76b0fb4a0315
# 45  5b41fe2373fe25002c0cc20c
# 46  57efae33498ed8b7dbc03127
# 47  4e770f9062e12635171d3a83
# 48  4b65afd7f964a520aef92ae3
# 49  510ecdd3e4b0607cf4a3dd3c

# %%
dataframe_filtered2.name
# Out:
# 0                                  Restaurant 27
# 1          İstanbul Turkish & Kurdish Restaurant
# 2                        restaurant holliday inn
# 3                                 The Restaurant
# 4                       G's Winebar & Restaurant
# 5                       Gandhi Indian Restaurant
# 6                      Cedar Lebanese Restaurant
# 7                                      Loch Fyne
# 8                    Po-Young Chinese Restaurant
# 9                        Victoriana's Restaurant
# 10           Deep Blue Restaurant, Southsea Pier
# 11                      G's Winebar & Restaurant
# 12                           sandip's restaurant
# 13                     Debenhams Restaurant/Café
# 14          Jmart Japanese and Korean Restaurant
# 15                                     Debenhams
# 16                     Sealevel Restaurant & Bar
# 17                              The George Hotel
# 18                        113 Restaurant And Bar
# 19    J Mart Japanese & Korean Restaurant 一嵐日韓料理
# 20             Golden Emperor Chinese Restaurant
# 21         Chimes Restaurant At Highbury College
# 22                       Penang Laksa Restaurant
# 23                                        Prezzo
# 24                                        Sakura
# 25                      Sarah turkish Restaurant
# 26                              Agora Restaurant
# 27                                    Great Wall
# 28                            Kung Fu Restaurant
# 29                              sarah restaurant
# 30                            Touareg restaurant
# 31                     @Asia Japanese Restaurant
# 32                   Nirvana Restaurant Southsea
# 33                              Dubai Restaurant
# 34                                       Bobby's
# 35                       Buffalo Cafe Restaurant
# 36                    Highbury Cafe & Restaurant
# 37              Pebbles Fish And Wine Restaurant
# 38           Pitch Side Restaurant, Fratton Park
# 39                         Goa Indian Restaurant
# 40                                        Bodrum
# 41              Twins Chinese Hot Pot Restaurant
# 42                      Nino's Cafe & Restaurant
# 43                  Bombay Bay Indian Restaurant
# 44                                   T & J Mahal
# 45              Chef’s Delight Cafe & Restaurant
# 46                    Tony's Café and Restaurant
# 47                         The Solent Restaurant
# 48                                   ASK Italian
# 49                              Twins Korean BBQ
# Name: name, dtype: object

# %%
venues_map4 = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map 

# add a red circle marker
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Portsmouth Harbour',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map4)

# add restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered2.lat, dataframe_filtered2.lng, dataframe_filtered2.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map4)

# display map
venues_map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
dataframe_filtered2.categories
# Out:
# 0             French Restaurant
# 1            Turkish Restaurant
# 2            English Restaurant
# 3                          Café
# 4                        Winery
# 5              Asian Restaurant
# 6           Lebanese Restaurant
# 7            Seafood Restaurant
# 8            Chinese Restaurant
# 9                Breakfast Spot
# 10           English Restaurant
# 11                     Wine Bar
# 12                   Restaurant
# 13                         Café
# 14          Japanese Restaurant
# 15             Department Store
# 16                   Restaurant
# 17                   Restaurant
# 18                   Restaurant
# 19          Japanese Restaurant
# 20           Chinese Restaurant
# 21                   Restaurant
# 22             Malay Restaurant
# 23           Italian Restaurant
# 24          Japanese Restaurant
# 25                         None
# 26             Greek Restaurant
# 27           Chinese Restaurant
# 28                   Restaurant
# 29    Middle Eastern Restaurant
# 30                         None
# 31          Japanese Restaurant
# 32            Indian Restaurant
# 33    Middle Eastern Restaurant
# 34           Italian Restaurant
# 35     Mediterranean Restaurant
# 36                         Café
# 37                   Restaurant
# 38               Soccer Stadium
# 39            Indian Restaurant
# 40           Turkish Restaurant
# 41           Chinese Restaurant
# 42                         None
# 43            Indian Restaurant
# 44            Indian Restaurant
# 45                   Restaurant
# 46               Breakfast Spot
# 47                         Café
# 48           Italian Restaurant
# 49            Korean Restaurant
# Name: categories, dtype: object

# %%
port_grouped = dataframe_filtered2.groupby('categories').mean().reset_index()
port_grouped
# Out:
#                    categories        lat       lng  distance
# 0            Asian Restaurant  50.810489 -1.078856   3071.00
# 1              Breakfast Spot  50.798002 -1.161056   4281.00
# 2                        Café  50.808747 -1.110709   4410.25
# 3          Chinese Restaurant  50.795314 -1.091644   3394.50
# 4            Department Store  50.800040 -1.090082   2955.00
# 5          English Restaurant  50.784018 -1.080661   4734.00
# 6           French Restaurant  50.780903 -1.080822   5009.00
# 7            Greek Restaurant  50.784693 -1.088026   4379.00
# 8           Indian Restaurant  50.789473 -1.071518   4827.75
# 9          Italian Restaurant  50.829285 -1.134463   3697.00
# 10        Japanese Restaurant  50.799260 -1.083330   3617.50
# 11          Korean Restaurant  50.789471 -1.072915   4641.00
# 12        Lebanese Restaurant  50.787354 -1.080876   4431.00
# 13           Malay Restaurant  50.804248 -1.078895   3329.00
# 14   Mediterranean Restaurant  50.787947 -1.082008   4329.00
# 15  Middle Eastern Restaurant  50.790246 -1.075737   4445.50
# 16                 Restaurant  50.811512 -1.125673   3895.00
# 17         Seafood Restaurant  50.794419 -1.106634   2822.00
# 18             Soccer Stadium  50.797236 -1.064455   4597.00
# 19         Turkish Restaurant  50.785926 -1.083122   4490.00
# 20                   Wine Bar  50.804035 -1.090426   2652.00
# 21                     Winery  50.802148 -1.124063   1794.00

# %%
venues_map5 = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map

# add a red circle marker
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Portsmouth Harbour',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map5)


marker_cluster = MarkerCluster().add_to(venues_map5)

for lat, lng, label in zip(dataframe_filtered2.lat, dataframe_filtered2.lng, dataframe_filtered2.categories):
    folium.Marker(
    location=[lat, lng],
    popup=label,
    icon=None,
    ).add_to(marker_cluster)


venues_map5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
port_grouped_sorted = port_grouped.sort_values('distance',ascending=True)
port_grouped_sorted
# Out:
#                    categories        lat       lng  distance
# 21                     Winery  50.802148 -1.124063   1794.00
# 20                   Wine Bar  50.804035 -1.090426   2652.00
# 17         Seafood Restaurant  50.794419 -1.106634   2822.00
# 4            Department Store  50.800040 -1.090082   2955.00
# 0            Asian Restaurant  50.810489 -1.078856   3071.00
# 13           Malay Restaurant  50.804248 -1.078895   3329.00
# 3          Chinese Restaurant  50.795314 -1.091644   3394.50
# 10        Japanese Restaurant  50.799260 -1.083330   3617.50
# 9          Italian Restaurant  50.829285 -1.134463   3697.00
# 16                 Restaurant  50.811512 -1.125673   3895.00
# 1              Breakfast Spot  50.798002 -1.161056   4281.00
# 14   Mediterranean Restaurant  50.787947 -1.082008   4329.00
# 7            Greek Restaurant  50.784693 -1.088026   4379.00
# 2                        Café  50.808747 -1.110709   4410.25
# 12        Lebanese Restaurant  50.787354 -1.080876   4431.00
# 15  Middle Eastern Restaurant  50.790246 -1.075737   4445.50
# 19         Turkish Restaurant  50.785926 -1.083122   4490.00
# 18             Soccer Stadium  50.797236 -1.064455   4597.00
# 11          Korean Restaurant  50.789471 -1.072915   4641.00
# 5          English Restaurant  50.784018 -1.080661   4734.00
# 8           Indian Restaurant  50.789473 -1.071518   4827.75
# 6           French Restaurant  50.780903 -1.080822   5009.00

# %%
print('There are {} uniques categories.'.format(len(port_grouped_sorted['categories'].unique())))
# Out:
# There are 22 uniques categories.

# %%
# set number of clusters
kclusters = 5

port_grouped_clustering = port_grouped.drop('categories', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(port_grouped_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([0, 1, 1, 2, 0, 4, 4, 1, 4, 2], dtype=int32)

# %%
# add clustering labels
port_grouped_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

port_grouped_sorted.head() # check the last columns!
# Out:
#     Cluster Labels          categories        lat       lng  distance
# 21               0              Winery  50.802148 -1.124063    1794.0
# 20               1            Wine Bar  50.804035 -1.090426    2652.0
# 17               1  Seafood Restaurant  50.794419 -1.106634    2822.0
# 4                2    Department Store  50.800040 -1.090082    2955.0
# 0                0    Asian Restaurant  50.810489 -1.078856    3071.0

# %%
port_grouped_sorted.loc[port_grouped_sorted['Cluster Labels'] == 0, port_grouped_sorted.columns[[1] + list(range(5, port_grouped_sorted.shape[1]))]]
# Out:
#            categories
# 21             Winery
# 0    Asian Restaurant
# 18     Soccer Stadium
# 8   Indian Restaurant

# %%
port_grouped_sorted.loc[port_grouped_sorted['Cluster Labels'] == 1, port_grouped_sorted.columns[[1] + list(range(5, port_grouped_sorted.shape[1]))]]
# Out:
#                    categories
# 20                   Wine Bar
# 17         Seafood Restaurant
# 10        Japanese Restaurant
# 7            Greek Restaurant
# 12        Lebanese Restaurant
# 15  Middle Eastern Restaurant
# 5          English Restaurant

# %%
port_grouped_sorted.loc[port_grouped_sorted['Cluster Labels'] == 2, port_grouped_sorted.columns[[1] + list(range(5, port_grouped_sorted.shape[1]))]]
# Out:
#             categories
# 4     Department Store
# 16          Restaurant
# 1       Breakfast Spot
# 2                 Café
# 19  Turkish Restaurant

# %%
port_grouped_sorted.loc[port_grouped_sorted['Cluster Labels'] == 3, port_grouped_sorted.columns[[1] + list(range(5, port_grouped_sorted.shape[1]))]]
# Out:
#           categories
# 6  French Restaurant

# %%
port_grouped_sorted.loc[port_grouped_sorted['Cluster Labels'] == 4, port_grouped_sorted.columns[[1] + list(range(5, port_grouped_sorted.shape[1]))]]
# Out:
#                   categories
# 13          Malay Restaurant
# 3         Chinese Restaurant
# 9         Italian Restaurant
# 14  Mediterranean Restaurant
# 11         Korean Restaurant

# %%
# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lng, poi, cluster in zip(port_grouped_sorted['lat'], port_grouped_sorted['lng'], port_grouped_sorted['categories'], port_grouped_sorted['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(venues_map4)
       
venues_map4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
